# %%
# Сбор ссылок на модели
import requests
from pprint import pprint 
from bs4 import BeautifulSoup 
import time
import pandas as pd
from datetime import datetime
import pdb

def models_list_in_product_category(url, category_len=1): 
#Скачиваниие перечня всех устройств в категории католога ya.маркета

    models_list = list()     #список словарей с моделями с названиеми и ссылками на модели
    
    page = 1 #номер страницы выдачи
    pages_full = True #есть ли целевой контент на очередной странице
    
    while pages_full:
        if page > 1:
            page_url = url + '&page=' + str(page) + '&onstock=1&local-offers-first=0'
            if page == 2:
                referer = url + '&onstock=1&local-offers-first=0'
     
            else:   
                referer = url + '&page=' + str(page-1) + '&onstock=1&local-offers-first=0'
        else:
            page_url = url + '&onstock=1&local-offers-first=0'
            referer = 'https://market.yandex.ru/catalog--kompiuternaia-tekhnika/54425'
        
        print(referer)
            
            
           
        header = {
        'Referer' : referer,
        'Accept' : 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'Accept-Encoding' : 'gzip, deflate, br',
        'Accept-Language' : 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
        'Connection' : 'keep-alive',
        'Sec-Fetch-Mode' : 'navigate',
        'Sec-Fetch-Site' : 'same-origin',
        'Sec-Fetch-User':'?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
        }
    
  
        ya_cookies = {
            'yandexuid' : '1316442951370867155', 
            'fuid01' : '4f310da92e0e9ff0.vHkMwDo78qH5TTmHx-stTeCpjL9q0oCG-kHm-t1yw00rSnf7Uxj5eqXaFjpO-Ji3kSQu-TbS-duDcL4tBTDDknJm0Xp2PwtEYgzI74M0t3XEplZr69TXugVdbykMuUYo; yp=1571397397.shlos.0#1600341397.p_sw.1568805397#1572440968.ygu.1#1585616974.szm.1:1680x1050:1614x887', 
            '_ym_uid' : '1478001885185024594',
            'i' : '8k0m5URcQTs/D8+3VhGAv5WDga2dnppzBVV1QJC90LIBHvPMRGJZCfTnVJ0n+Mn0B1Jzd5hn+0ZsECAkAdHOR+LT58Y=',
            'mda':'0', 
            'my' : 'YwA=', 
            'yabs' : '-frequency=/4/0000000000000000/XtroS9mt81g-FMsSDoUqLB1md3SW/', 
            '_ym_isad' : '=2', 
            'yandex_gid' : '213', 
            'font_loaded' : 'YSv1', 
            '_ym_wasSynced' : '%7B%22time%22%3A1569848959698%2C%22params%22%3A%7B%22eu%22%3A0%7D%2C%22bkParams%22%3A%7B%7D%7D', 
            '_ym_d' : '1569848960', 
            '_ym_visorc_160656':'b', 
            '_ym_visorc_45411513':'b', 
            'markethistory':'<h><cm>6427101-9238862</cm><cm>6427101-8538765</cm><m>106905-10467479</m><m>432460-7691987</m><c>7156311</c></h>', 
            'cmp-merge':'true', 
            'reviews-merge':'true', 
            'head-banner-sovetnik':'%7B%22closingCounter%22%3A0%2C%22showingCounter%22%3A1%2C%22shownAfterClicked%22%3Afalse%2C%22isClicked%22%3Afalse%7D; head-banner-sovetnik-info=%7B%22closingCounter%22%3A0%2C%22showingCounter%22%3A1%2C%22shownAfterClicked%22%3Afalse%2C%22isClicked%22%3Afalse%7D', 
            'head-banner':'%7B%22closingCounter%22%3A0%2C%22showingCounter%22%3A526%2C%22shownAfterClicked%22%3Afalse%2C%22isClicked%22%3Afalse%7D; currentRegionId=213', 
            'currentRegionName':'%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D1%83', 
            'pof':'%7B%22clid%22%3A%5B%22505%22%5D%2C%22mclid%22%3Anull%2C%22distr_type%22%3Anull%2C%22vid%22%3Anull%2C%22opp%22%3Anull%7D', 
            'cpa':'%7B%22clid%22%3A%5B%22505%22%5D%2C%22mclid%22%3Anull%2C%22distr_type%22%3Anull%2C%22vid%22%3Anull%2C%22opp%22%3Anull%7D; visits=1569848974-1569848974-1569848974; parent_reqid_seq=d42a92a5871ff61374b913eb3f4ccf8f%2Cce5b53e8a009fae941bde9127ffccf95%2C07c761fd008a9de5656c84921bf0aa02; utm_campaign=face_abovesearch', 
            'utm_source' : 'face_abovesearch', 
            'uid':'AABbhl2R/o6riwEABZ1KAg==', 
            'js':'1', 
            'first_visit_time' : '2019-09-30T16%3A09%3A25%2B03%3A00', 
            'HISTORY_UNAUTH_SESSION':'true', 
            'fonts-loaded':'1', 
            'ugcp':'1',
            'viewtype' : 'list'
        }
 
    
        response = requests.get(page_url, headers = header, cookies = ya_cookies)

#        pdb.set_trace()
        
        if response.status_code == 200:
            print('поехали ', page_url)
            iter_page_soup = BeautifulSoup(response.text, 'html.parser')
            
        #Пречень ссылок на модели
            rows_models = iter_page_soup.find_all('div', class_='n-snippet-card2 i-bem b-zone b-spy-visible b-spy-events')
#            'n-snippet-card2 i-bem b-zone b-spy-visible b-spy-events b-spy-visible_js_inited b-zone_js_inited n-snippet-card2_js_inited b-spy-events_js_inited'

#            rows_models = iter_page_soup.find_all('div', class_='n-snippet-card2__title') 
            if len(rows_models) < 48:
                pages_full = False
            
            if len(rows_models) != 0:
                print(page, len(rows_models))
#                print(rows_models)
                
        #Перебирраем модельки на странице       

                for row in rows_models:
                #И рассовыем их по ключам словаря model_dict
                        model_dict = dict()
                        model_link = row.find('h3', class_='n-snippet-card2__title').find('a')
                        model_dict['Href'] = model_link['href'] #ссылка на страницу модели
                    #вообще, надо прибавлять туда   'https://market.yandex.ru', однако excel ограничиает гипперссылки 255 символами
                        name = model_link.text.split()
                    # Смотрим формат названия категории
                        model_dict['Category'] = name[0]
                        
                        vendor_position = 1
                        if category_len > 1:
                            for i in range(1, category_len):
                                model_dict['Category'] += ' ' + name[i]
                                vendor_position += 1
                        #имя вендора - первое слово после названия категории продукта
                        model_dict['Vendor'] = name[vendor_position]      

                    # Смотрим обобщенная модель или отдельная конфигурация только для ноутбуков
                        if model_dict['Category'] == 'Ноутбук':
                            if '/' in model_link.text:
                                model_dict['Assemble'] = False
                            else:
                                model_dict['Assemble'] = True
                        else:
                            model_dict['Assemble'] = True

                        mod_name = ''
                        for word in name[category_len:]:
                            mod_name += word + ' '
                        model_dict['Name'] = mod_name[:-1]
                    # Пихаем словарь модели в общий список    
                        print(model_dict['Name'] )
                        models_list.append(model_dict)

                page += 1
          
            else:
                capcha_quest = iter_page_soup.find('title')
                print(capcha_quest)
                if capcha_quest.text == 'ÐÐ¹!':
                    time.sleep(1)
                else:
                    print('фигня какая-то')
                    break
                 
            time.sleep(2)
        
       
        else:
            print('облом... ', response.status_code)
            return  models_list
        
    return  models_list
    
Categories = {
    'Ноутбук': {
        'url': 'https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013',
        'category': ['Ноутбук']
    },
    'Монитор': {
        'url': 'https://market.yandex.ru/catalog--monitory/54539/list?hid=91052',
        'category': ['Монитор']
    },
    'Проектор': {
        'url': 'https://market.yandex.ru/catalog--multimedia-proektory/60865/list?hid=191219',
        'category': ['Проектор']
    },
    'ИБП': {
        'url': 'https://market.yandex.ru/catalog--istochniki-bespereboinogo-pitaniia/59604/list?hid=91082'
        'category': ['Интерактивный ИБП',
                    'Резервный ИБП',
                    'ИБП с двойным преобразованием']
    }
}   

#url = 'https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013'    
#url = 'https://market.yandex.ru/catalog--planshety/54545/list?hid=6427100'
#url = 'https://market.yandex.ru/catalog--monitory/54539/list?hid=91052'
#url = 'https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&onstock=1&local-offers-first=0'
#url = 'https://market.yandex.ru/catalog--monobloki/61323/list?hid=12382295'
#url = 'https://market.yandex.ru/catalog--istochniki-bespereboinogo-pitaniia/59604/list?hid=91082'
#url = 'https://market.yandex.ru/catalog--multimedia-proektory/60865/list?hid=191219'
#url = 'https://market.yandex.ru/catalog--smartfony/16814639/list?hid=91491&glfilter=16816262%3A16816264'
#url = 'https://market.yandex.ru/catalog--umnye-chasy-i-braslety/56034/list?hid=10498025'
#url = 'https://market.yandex.ru/catalog--pulsometry-i-shagomery/60855/list?hid=1009489'
#url = 'https://market.yandex.ru/catalog--umnye-chasy-i-braslety/56034/list?hid=10498025&glfilter=10769021%3A12113496'
category_len = 1 #число слов в названии категории. 'Ноутбук' - 1;'Твердотельный накопитель' - 2

category = 'Монитор'

url = Categories[category]['url']
category_ls = Categories[category]['category']

list_for_work = models_list_in_product_category(url, category_ls)
print(len(list_for_work))

df = pd.DataFrame(list_for_work)

#Убиряем дубли
df.drop_duplicates(subset=['Name'], inplace = True)
df.reset_index

print(len(df))

#пихаем в файл

now = datetime.now().strftime('%b-%Y--%d-%H-%M')

excel_file_name = 'Price_link_list/' + df['Category'][0].split()[0].replace('"','') + '-ссылки от ' + now + '.xlsx'
df.to_excel(excel_file_name)
# Out:
# https://market.yandex.ru/catalog--kompiuternaia-tekhnika/54425
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&onstock=1&local-offers-first=0
# 1 48
# ASUS VivoBook 15 X512
# Apple MacBook Pro 16 with Retina display and Touch Bar Late 2019
# Xiaomi RedmiBook 14"
# ASUS ZenBook 14 UX433
# ASUS VivoBook S13 S330
# Apple MacBook Pro 13 with Retina display and Touch Bar Mid 2019
# ASUS TUF Gaming FX505
# Acer ASPIRE 3 (A315-21)
# Xiaomi Mi Notebook Pro 15.6 2019
# Lenovo IdeaPad S340-15 AMD
# Lenovo Yoga S740
# ASUS ZenBook 13 UX331UA
# Xiaomi Mi Notebook Air 13.3" 2019
# Apple MacBook Air 13 дисплей Retina с технологией True Tone Mid 2019
# Lenovo Ideapad 330 15 Intel
# DELL XPS 15 7590
# DELL Vostro 5590
# DELL Inspiron 5593
# HP 250 G6
# Lenovo Ideapad L340 (15) Gaming
# Acer ASPIRE 3 (A315-34)
# HP Pavilion Gaming 15-ec0000
# Acer ASPIRE 3 (A315-54K)
# ASUS VivoBook S15 S530
# HP ProBook 440 G6
# Acer Swift 3 (SF314-41)
# DELL Inspiron 5491 2-in-1
# DELL G5 15 5587
# HP 250 G7
# Xiaomi Mi Notebook Pro 15.6 GTX
# Acer Extensa 15 EX215-51
# DELL Inspiron 5490
# DELL INSPIRON 5370
# Acer SPIN 3 (SP314-53N)
# DELL INSPIRON 3793
# DELL LATITUDE 5290
# Acer SWIFT 3 (SF314-57)
# Lenovo Ideapad 330s 14 Intel
# DELL Vostro 3481
# Apple MacBook Mid 2017
# Acer ASPIRE 3 (A315-53)
# HP 15-da1000
# Acer Nitro 5 (AN517-51)
# HP 15-rb000
# Irbis NB211
# DELL XPS 13 9370
# Acer SWIFT 1 (SF114-32)
# HP PAVILION 15-cw1000
# Acer Extensa EX2540
# Lenovo ThinkPad L390
# ASUS Laptop 15 X509
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=3&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=4&onstock=1&local-offers-first=0
# 4 48
# Xiaomi Mi Notebook Air 12.5"
# Acer Aspire 3 (A315-55G)
# MSI PS42 Modern 8MO
# Xiaomi Mi Notebook 15.6 Lite
# Acer ASPIRE 3 (A315-22)
# Acer ASPIRE ES1-732
# ASUS ZenBook 13 UX333FA
# HP ProBook 450 G5
# ASUS VivoBook X540
# Xiaomi Mi Notebook Pro 15.6
# HP Envy 13-ad000
# DELL INSPIRON 5482 2-in-1
# ASUS FX753VD
# ASUS X540MA
# Microsoft Surface Laptop
# ASUS ZenBook Pro Duo UX581
# DELL INSPIRON 3585
# ASUS X507UF
# ASUS VivoBook E403NA
# DELL G3 15 3590
# ASUS VivoBook 15 X542UF
# ASUS Zenbook 14 UX431
# HP Envy 15-ds0000 x360
# ASUS ROG Strix G531
# Acer ASPIRE 5 (A517-51G)
# Lenovo Ideapad S540 14 AMD
# Microsoft Surface Book 2 13.5
# DELL Inspiron 3781
# ASUS VivoBook 17 X712
# Lenovo V340-17
# Lenovo Ideapad 330-17 Intel
# MSI Modern 14 A10M
# KREZ N1403S Travel
# HP 15-dw0000
# Lenovo Ideapad 530s 15
# DELL INSPIRON 3180
# Lenovo V330 14
# ASUS Zenbook UX310UA
# Acer ASPIRE 3 (A315-41)
# Apple MacBook Pro 15 with Retina display Mid 2018
# Lenovo Yoga 530-14 Intel
# Lenovo IdeaPad S145
# DELL Inspiron 3583
# ASUS TUF Gaming FX504
# ASUS X540UB
# DIGMA EVE 101
# HP PAVILION 15-cs0000
# HP 15-ra000
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=4&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=5&onstock=1&local-offers-first=0
# 5 48
# MSI GL63 8RC
# DELL Inspiron 5390
# DELL XPS 13 7390
# DELL INSPIRON 5770
# DELL Vostro 5581
# MSI GL75 9SCK
# HP Elite Dragonfly
# Apple MacBook Pro 13 with Retina display and Touch Bar Mid 2018
# ASUS K540UA
# Acer ASPIRE 7 (A715-72G)
# Acer ASPIRE 3 (A315-53G)
# Xiaomi Mi Gaming Laptop 2019
# Razer Blade Stealth 13.3
# DELL Vostro 3583
# Acer ASPIRE E 15 (E5-576G)
# MSI PS63 Modern 8RC
# Microsoft Surface Book 2 15
# ASUS TUF Gaming FX505DT
# ASUS VivoBook 17 X705UA
# DELL INSPIRON 5391
# HP Envy 13-ar0000 x360
# ASUS E203MA
# DELL Vostro 7590
# HP PAVILION 15-bc400
# ASUS VivoBook 15 X505
# Microsoft Surface Laptop 3 15
# Lenovo V330 15
# Acer Aspire 3 (A315-54)
# ASUS VivoBook Max X541UV
# HP PAVILION 13-an0000
# Lenovo IdeaPad 320 15 Intel
# DELL LATITUDE 5490
# HP 620
# Acer ASPIRE 3 (A315-41G)
# MSI Prestige 15 A10SC
# Xiaomi RedmiBook 14" Enhanced Edition
# HP ProBook x360 440 G1
# Acer SPIN 1 (SP111-32N)
# Acer Swift 3 (SF314-57G)
# ASUS ROG Strix G731
# MSI PS42 Modern 8RA
# ASUS X555QA
# ASUS Vivobook 17 X705MA
# HP 15-bw000
# MSI GL63 8SDK
# Acer SWIFT 3 (SF314-58G)
# ASUS VivoBook 15 D540
# Irbis NB245S
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=5&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=6&onstock=1&local-offers-first=0
# 6 48
# HP ProBook 430 G5
# Acer Aspire 5 (A515-54)
# HP 240 G7
# Acer SWIFT 3 (SF314-58)
# ASUS R556
# Lenovo THINKPAD X270
# Lenovo Ideapad S540 14 intel
# HP 14-ck0000
# HP ProBook 455 G6
# Acer SWIFT 3 (SF314-54)
# ASUS ZenBook 13 UX331UN
# ASUS X570UD
# Acer ASPIRE 3 (A317-51)
# Xiaomi RedmiBook 14" Ryzen Edition
# HP 250 G5
# ASUS VivoBook Pro 17 N705
# Acer Aspire 5 (A515-52G)
# Xiaomi Mi Notebook Pro 15.6" Enhanced Edition 2019
# Lenovo IdeaPad 320s 13
# DELL G3 17 3779
# DELL Vostro 3568
# Lenovo Legion Y540-15
# HP OMEN 15-dc0000
# DELL LATITUDE 7490
# Xiaomi Mi Gaming Laptop Enhanced Edition
# Lenovo Ideapad 330s 14 AMD
# DELL G3 15 3579
# HP PAVILION 15-cs3000
# Acer SWIFT 3 (SF314-55)
# Acer ASPIRE 3 (A315-33)
# DELL Vostro 3580
# HP PAVILION 14-ce0000
# DELL Latitude 3400
# HUAWEI MateBook 13
# HP PAVILION 15-dp0000
# DELL LATITUDE 7390
# DIGMA CITI E602
# DELL XPS 13 9360
# Alienware Area-51m
# Acer Extensa EX2519
# Irbis NB133
# DELL LATITUDE E6400
# ASUS Zenbook BX433FN
# ASUS X540MB
# ASUS ZenBook 13 UX333FN
# HP 240 G6
# HP ProBook 440 G5
# HP 15-af100
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=6&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=7&onstock=1&local-offers-first=0
# 7 48
# HP PAVILION 14-ce2000
# ASUS ROG Strix G GL531
# HP ProBook 470 G5
# DIGMA EVE 100
# HP 15-bs000
# HP PAVILION 14-ba000 x360
# ASUS VivoBook 15 X542UA
# DELL XPS 13 Ultrabook
# Lenovo Legion Y530
# Lenovo ThinkPad T590
# Xiaomi Mi Gaming Laptop
# Xiaomi Mi Notebook 15.6 2019
# ASUS VivoBook S14 S406UA
# HP 17-ca1000
# ASUS Zenbook S13 UX392
# Acer ASPIRE ES1-533
# HP 14-cm1000
# ASUS E406MA
# DELL Vostro 3480
# ASUS VivoBook 17 X705UB
# ASUS X560UD
# ASUS X507MA
# HP 15-ba000
# HP 15-bs700
# HP PAVILION 14-ce3000
# Lenovo ThinkPad Edge E480
# HP 15-ac100
# ASUS ZenBook UX430UA
# ASUS VivoBook 14 F412
# HP 630
# Lenovo IdeaPad S540-13
# Lenovo ThinkPad X1 Extreme
# Lenovo V320 17
# ASUS VivoBook S15 S510
# HP 255 G3
# Acer ASPIRE 1 (A114-32)
# DELL Vostro 5370
# HP 6510b
# HP ZBook Studio G5
# Acer Aspire 3 (A315-32)
# Acer Extensa 15 EX215-51K
# HP PAVILION 15-cs2000
# Acer ASPIRE 3 (A315-21G)
# Acer ASPIRE ES1-572
# HP ProBook 430 G4
# Prestigio SmartBook 141C
# DELL PRECISION M7520
# Irbis NB241
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=7&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=8&onstock=1&local-offers-first=0
# 8 48
# Acer TRAVELMATE P238-M
# ASUS ROG GL504
# HUAWEI MateBook X Pro
# MSI GL63 8RD
# HP PAVILION 15-ck000
# DIGMA CITI E603
# DELL Latitude 5300
# Apple MacBook Late 2018
# HP PAVILION 15-cc000
# ASUS ROG G703
# HP PAVILION 15-bc500
# Acer ASPIRE 5 (A515-41G)
# DELL LATITUDE 5590
# Acer Extensa EX2511G
# Samsung X1
# HP 255 G5
# GIGABYTE AERO 15
# Acer TravelMate P2 (TMP215-51)
# HP 14-am000
# Acer SWIFT 3 (SF314-56G)
# HP EliteBook 850 G6
# HP 14-cf0000
# Acer SWIFT 1 (SF113-31)
# HP ProBook 5320m
# Acer ASPIRE E 15 (E5-576)
# Acer SWIFT 7 (SF714-51T)
# ASUS X507
# Lenovo THINKPAD X230
# Irbis NB245B
# DELL Precision 7540
# DELL LATITUDE 3480
# HP PAVILION 15-cr0000 x360
# Lenovo Ideapad S530 13
# ASUS VivoBook S14 S431
# HP PAVILION 15-dk0000
# ASUS X543UB
# HP 17-by1000
# DIGMA CITI E401
# HP 11-ab100 x360
# ASUS N552VX
# Acer ASPIRE S5-371
# Acer Nitro 5 (AN515-51)
# ASUS R540
# HP PAVILION POWER 15-cb000
# MSI GL63 8SC
# Irbis NB52
# Acer TravelMate P2 (TMP215-51G)
# ASUS ZenBook Pro 14 UX480FD
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=8&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=9&onstock=1&local-offers-first=0
# 9 48
# HP ProBook 455R G6
# ASUS VivoBook Flip 14 TP401
# Acer SWIFT 3 (SF314-54G)
# ASUS X540SA
# DELL INSPIRON 5558
# ASUS E406SA
# Acer Aspire 5 (A515-52)
# Lenovo IdeaPad 100 15
# HP 14s-dq0000
# HP ProBook 445 G6
# Lenovo IdeaPad 320 17 Intel
# HP EliteBook 840 G4
# DELL LATITUDE 3490
# Lenovo IdeaPad 300 15
# Fujitsu LIFEBOOK A357
# Lenovo IdeaPad 320 15 AMD
# Lenovo Ideapad 530s 14 AMD
# HP 14-bs000
# Acer ASPIRE 7 (A715-71G)
# HP 15s-fq0000
# HP 350 G2
# HP PAVILION 15-cw0000
# Alienware 15 R4
# DELL Latitude 3500
# HP PAVILION 15-cc100
# Lenovo ThinkPad Edge E590
# Acer Extensa 15 EX215-21G
# Acer Swift 3 (SF314-41G)
# HP 14-bp100
# HP PAVILION 15-au100
# DELL XPS 15 9570
# ASUS VivoBook A540
# MSI GP75 Leopard 9SD
# ASUS R540NV
# HP PAVILION 15-cd000
# ASUS FX503VD
# MSI GF63 8RD
# ASUS Vivobook 17 X705MB
# HP PAVILION 15-cs1000
# DELL Inspiron 3580
# Haier HI133
# HP 15-af000
# ASUS R541UV
# Lenovo IdeaPad Z5075
# HP OMEN 15-dc1000
# HP 15-ay100
# Acer Predator 15 (G9-593)
# ASUS VivoBook Max X541NA
# Lenovo Legion Y740-17
# HP EliteBook 2570p
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=11&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=12&onstock=1&local-offers-first=0
# 12 48
# DELL Latitude 5491
# Lenovo V510 14
# Acer Predator Triton 900 (PT917-71)
# DELL INSPIRON 5758
# HP PAVILION 15-ab100
# DELL Vostro 5471
# ASUS Zenbook Flip UX562
# Lenovo G50-45
# HP Pavilion Gaming 15-cx0000
# DELL INSPIRON 3552
# HP 15-bw500
# ASUS ZenBook Flip UX561UN
# Lenovo IdeaPad S340-14 AMD
# DELL INSPIRON 5767
# Lenovo ThinkPad Edge E495
# ASUS VivoBook 15 X510UQ
# Irbis NB153
# DELL Latitude 5501
# Acer SWIFT 3 (SF314-52G)
# DELL XPS 15
# DELL LATITUDE E5420
# RoverBook Roverbook B510
# Acer TravelMate P2 (TMP278-M)
# Acer ASPIRE E5-571G-37FY
# DELL INSPIRON 3567
# DELL Vostro 5568
# ASUS X540LA
# HP 14-bp000
# Prestigio SmartBook 133S
# ASUS X555BP
# Lenovo Ideapad 330-14 AMD
# HP ProBook 450 G4
# Apple MacBook Pro 15 with Retina display Late 2016
# Acer Swift 5 (SF514-54T)
# ASUS X540SC
# Lenovo Ideapad L340 (17) Gaming
# Lenovo IdeaPad 520s 14
# Lenovo IdeaPad 110 17 AMD
# HP Stream 14-ax000
# ASUS X540NV
# ASUS ROG GL752VW
# Acer ASPIRE E5-573G-52PV
# ASUS VivoBook 15 X540UA
# DELL XPS 15 9575
# ASUS FX570
# ASUS F540
# MSI GS65 Stealth 9SD
# DELL INSPIRON 7577
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=12&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=13&onstock=1&local-offers-first=0
# 13 48
# HP Spectre 13-v000
# Acer Aspire V Nitro (VN7-593G)
# ASUS ROG GL503
# MSI GL63 8RCS
# Prestigio Smartbook 141 C2
# Lenovo V310 15
# ASUS X554LJ
# HP ZBook x2 G4
# DELL LATITUDE 3590
# Acer Extensa 2510G-38H2
# HP ProBook 430 G3
# Acer ASPIRE ES1-523
# DELL INSPIRON 3576
# HP 15-ra100
# Acer Predator Helios 300 (PH315-52)
# HP 17-ak000
# ASUS VivoBook 15 X542UN
# HP OMEN X 17-ap000
# Lenovo Legion Y520
# ASUS VivoBook S13 S330UA
# ASUS ZENBOOK UX305CA
# Acer ASPIRE V3-372
# MSI PS42 Modern 8RC
# ASUS ZenBook Pro 15 UX550GD
# HP ProBook 440 G3
# MSI GT63 Titan 8RG
# Lenovo Yoga 920-13
# HP OMEN 17-an000
# MSI GF75 Thin 8RC
# Lenovo IdeaPad 310 15 Intel
# Acer Predator Helios 300 (PH317-51)
# Lenovo IdeaPad Yoga 3 11
# HP ProBook 440 G4
# HP Envy 15-bq000 x360
# HP EliteBook 1040 G3
# Lenovo ThinkBook 13s
# ASUS ZenBook Pro 15 UX550GE
# ASUS ROG GL703
# ASUS ROG GL502VM
# Acer ASPIRE 7 (A717-72G)
# Lenovo Yoga S730
# ASUS Vivobook X556UQ
# Acer ASPIRE E5-573G-38TN
# Lenovo Yoga 520 14
# DELL INSPIRON 3565
# HP Spectre 13-af000
# Lenovo IdeaPad 320s 15
# DELL Precision 5540
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=13&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=14&onstock=1&local-offers-first=0
# 14 48
# HP Spectre 13-ap0000 x360
# Apple MacBook Air 13 Early 2015
# Lenovo THINKPAD T570
# ASUS VivoBook Max X541UJ
# Lenovo IdeaPad 720 15
# HP 255 G6
# HP 17-bs000
# HP EliteBook 840 G3
# Lenovo Legion Y740-15
# ASUS ROG GL753
# Acer Predator Helios 300 (G3-572)
# ASUS ZenBook U310UA
# ASUS X540LJ
# ASUS Zenbook UX310UQ
# Lenovo V110 15 Intel
# ASUS X555LJ
# Apple MacBook Pro 13 with Retina display and Touch Bar Mid 2017
# HP 250 G4
# HP ProBook 450 G2
# Acer ASPIRE 8942G-434G50Mi
# HP PAVILION 14-ba100 x360
# Lenovo B50 10
# Acer SWIFT 7
# DELL Latitude 5500
# HP 17-x000
# Acer Predator Helios 300 (PH317-52)
# ASUS FX502VM
# Acer Nitro 5 Spin (NP515-51)
# MSI GE63 8SF Raider RGB
# HP EliteBook 755 G5
# Alienware M17 R2
# Acer Nitro 5 (AN515-31)
# Lenovo ThinkPad P52s
# MSI GL73 8RC
# ASUS ZENBOOK UX303UB
# ASUS R540SC
# HP ProBook 650 G5
# HP PAVILION Gaming 15-ak000
# HP PAVILION 15-bc200
# HP 15-g200
# Acer Aspire 3 (A317-51G)
# ASUS VivoBook Pro 15 N580
# MSI GE75 Raider 9SF
# Lenovo ThinkPad Edge E580
# MSI GL72M 7RDX
# ASUS ZenBook 15 UX533FN
# ASUS ROG GL553VD
# ASUS K501UQ
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=14&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=15&onstock=1&local-offers-first=0
# 15 48
# MSI GL63 9SC
# HP Spectre 13-ae000 x360
# MSI GE75 Raider 9SG
# ASUS FX553VE
# Acer Aspire V Nitro (VN7-592G)
# Lenovo B50 70
# Lenovo V155
# ASUS A507UB
# HP Spectre 15-df0000 x360
# ASUS ROG GL502VS
# MSI GP62M 7RDX World of Tanks Edition
# Lenovo B71-80
# DELL LATITUDE 7370
# ASUS VivoBook Max X541SA
# HP EliteBook x360 1030 G2
# Lenovo THINKPAD Edge E470
# Acer TravelMate P2 (TMP2410-G2-M)
# HP Envy 13-ad100
# Lenovo THINKPAD X1 Carbon Ultrabook (5th Gen)
# Lenovo IdeaPad 110 15 AMD
# Razer Blade 15 Advanced (2018)
# Acer SPIN 5 (SP515-51GN)
# DIGMA CITI E404 PRO
# DELL INSPIRON 9100
# HP Spectre Folio 13-ak0000
# ASUS X555LB
# Haier ES34
# HP 17-p000
# ASUS X556UA
# Acer SWIFT 1
# ASUS X555LF
# MSI GS65 Stealth 8SE
# MSI GT75 8RF Titan
# HP OMEN 17-an100
# Lenovo B51-30
# HP ZBook 15 G3
# Lenovo ThinkPad T480s
# Acer ASPIRE 7 (A717-71G)
# ASUS VivoBook S15 S530FN
# DELL Vostro 3578
# ASUS ZenBook 13 UX331FN
# ASUS ZenBook Flip UX561UA
# ASUS N551VW
# ASUS VivoBook Max X541NC
# HP PAVILION 17-ab300
# ASUS F553MA
# ASUS X555YA
# HP PAVILION 15-bc000
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=15&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=16&onstock=1&local-offers-first=0
# 16 48
# HP PAVILION 14-cd0000 x360
# ASUS ZenBook Flip 13 UX362FA
# HP Envy 13-ah1000
# HP EliteBook 830 G5
# DELL INSPIRON 7559
# Acer SWIFT 5 (SF514-52T)
# HP Envy 17-bw0000
# MSI PS42 8RB
# DELL LATITUDE 7414
# DELL XPS 15 9560
# ASUS VivoBook 15 X505ZA
# ASUS X555LN
# HP ENVY 13-ag0000 x360
# Lenovo Yoga 730-13
# ASUS X751NA
# Acer ASPIRE E5-571G-36MP
# Lenovo Legion Y540-17
# DELL Vostro 1015
# HP PAVILION 15-ab000
# HP Envy 15-as100
# Alienware 15 R2
# Lenovo IdeaPad 320 17 AMD
# ASUS ROG GL552VW
# ASUS VivoBook Pro N752VX
# Acer SWIFT 5
# ASUS X751SV
# ASUS F402WA
# HP Envy 15-dr0000 x360
# DELL Vostro 1710
# Acer ASPIRE R7-372T-553E
# DIGMA EVE 403 PRO
# HP PAVILION 13-an1000
# HP 15-ac000
# ASUS TUF Gaming FX705DT
# Panasonic Toughbook CF-54
# ASUS VivoBook Max X541UA
# HP ZBook Studio x360 G5
# Lenovo IdeaPad 520 15
# ASUS ZENBOOK UX305UA
# MSI Alpha 15
# Acer TravelMate P2 (TMP2510-G2-M)
# ASUS X554LA
# Lenovo ThinkPad T480
# ASUS X756UQ
# Alienware 17
# HP EliteBook 1040 G4
# Lenovo ThinkBook 15
# HP Envy 15-cp0000 x360
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=16&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=17&onstock=1&local-offers-first=0
# 17 48
# MSI GS75 Stealth 9SE
# MSI GL73 9SEK
# Acer SWIFT 3 (SF314-51)
# Panasonic TOUGHBOOK CF-53
# Xiaomi Mi Notebook Air 13.3" 2017
# DELL INSPIRON 3157
# DELL Vostro 3350
# Lenovo ThinkPad L380
# HP ProBook 645 G4
# Acer ASPIRE E5-573G-39NW
# ASUS VivoBook 14 X405UA
# DIGMA CITI E600
# HP PAVILION 17-ab000
# Lenovo IdeaPad Flex 10
# ASUS X555UB
# ASUS X550LA
# MSI GL73 8SDK
# Alienware M17
# ASUS TUF Gaming FX505DD
# HP PAVILION 15-br000 x360
# ASUS VivoBook S14 S410
# HP EliteBook 745 G5
# HP 15-ac600
# DELL INSPIRON N5050
# Lenovo IdeaPad 510s 13
# Acer ASPIRE ES1-520-38XM
# HP Stream x360 11-aa000
# HP ProBook 445R G6
# ASUS ROG Zephyrus GM501
# Lenovo Yoga C930
# Acer ASPIRE F5-571G
# MSI GT75VR 7RF Titan Pro
# Haier LightBook S314
# ASUS X553MA
# Lenovo Legion Y730-17
# Lenovo ThinkPad L580
# HP EliteBook 735 G6
# DELL INSPIRON 5565
# Lenovo Yoga 730-15
# Acer ASPIRE E5-571G-539K
# Lenovo Legion Y545
# HP 17-p100
# DELL INSPIRON 5720
# Acer Nitro 7 (AN715-51)
# Lenovo IdeaPad 720s 14
# MSI GT75 Titan 9SG
# HP Envy 13-d100
# MSI P65 Creator 8RE
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=17&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=18&onstock=1&local-offers-first=0
# 18 48
# Lenovo ThinkPad X390
# MSI GL73 8SE
# KREZ N1304
# MSI GP75 Leopard 9SE
# HP Envy 13-ah0000
# Acer ASPIRE 5 (A517-51)
# Haier HI133L
# ASUS K501UW
# Lenovo Yoga 530-14 AMD
# HP PAVILION 15-p200
# Acer ASPIRE ES1-132-C2L5
# Lenovo ThinkPad Yoga 370
# Lenovo IdeaPad 720s 13
# DELL Precision 7740
# KREZ N1303
# ASUS ZenBook BX410UA
# Acer ASPIRE E5-573G-34JQ
# MSI GS65 Stealth Thin 8RE
# Acer SWIFT 5 (SF514-53T)
# MSI Creator 17M A9
# Acer Predator Helios 300 (PH317-53)
# HP Envy 15-as000
# ASUS AsusPro B9440UA
# MSI GF62 8RD
# Lenovo IdeaPad 110 15 Intel
# ASUS Zenbook 13 UX331UAL
# Alienware M15
# HP Envy 15-k100
# Acer Extensa EX2520
# ASUS Zenbook 3 Deluxe UX490UAR
# Acer SPIN 5 (SP515-51N)
# HP PAVILION g6-1100
# HP PAVILION 14-dd0000 x360
# DELL Vostro 3558
# MSI GF63 8RC
# DIGMA CITI E400
# Acer ASPIRE E5-573-34JQ
# MSI GS75 Stealth 9SF
# HP ProBook 640 G2
# Lenovo Yoga 900 13
# Lenovo IdeaPad 720s 15
# HP PAVILION 14-bf000
# MSI GE75 8SF Raider
# Acer Predator 17 (G5-793)
# DELL XPS 12 9250
# Lenovo IdeaPad Yoga 13
# Samsung R540
# Lenovo B70-80
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=18&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=19&onstock=1&local-offers-first=0
# 19 48
# HP 14-ck1000
# HP OMEN 17-cb0000
# HP 340S G7
# HP 17-y000
# DELL LATITUDE 7390 2-in-1
# Acer ASPIRE E5-571G-32BH
# HP ZBook 15u G6
# DELL Latitude 3301
# DELL Precision 3541
# MSI GL72M 7REX
# Lenovo Yoga 720 13
# Acer ASPIRE E5-571G-39TX
# Lenovo B570
# HP 14-cf1000
# HP EliteBook 840 G6
# HP EliteBook 840 G1
# ASUS Zenbook Pro UX450
# MSI GT62VR 7RE Dominator Pro
# ASUS ROG GL552VX
# HP ProBook 11 EE G2
# HP EliteBook x360 1030 G3
# HP 250 G3
# MSI GF75 THIN 9SC
# Acer Predator 17 (G9-793)
# Lenovo V110 15 AMD
# Acer ASPIRE E5-571G-37BH
# ASUS ROG GL553VE
# Samsung 535U4C
# Lenovo Yoga S940
# MSI GL62M 7REX
# ASUS TUF Gaming FX505DY
# MSI GF72 8RD
# Samsung 350V5C
# ASUS VivoBook 17 X705UF
# MSI GL73 8RD
# Sony VAIO Tap 11 SVT1122X9R
# ASUS TUF Gaming FX705DY
# Getac X500
# HP EliteBook 1030 G1
# MSI GL73 9SC
# Panasonic TOUGHBOOK CF-20
# ASUS ZenBook UX330UA
# MSI GT83VR 7RE Titan SLI
# HP EliteBook 820 G3
# MSI GL63 8SE
# ASUS FX553VD
# MSI GP72 7RD Leopard
# Samsung RV520
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=19&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=20&onstock=1&local-offers-first=0
# 20 48
# Lenovo ThinkPad T580
# Lenovo IdeaPad B575
# MSI GS75 Stealth 8SE
# Lenovo ThinkPad X1 Yoga (4th Gen)
# HP ProBook 640 G3
# ASUS R540SA
# MSI GP62 8RC WOT Edition
# HP Envy 15-cn1000 x360
# MSI PS42 8M
# MSI P65 Creator 9SF
# Alienware 17 R5
# MSI GE65 Raider 9SF
# HP ProBook 640 G5
# MSI GS63 8RE Stealth
# Acer TravelMate P6 (P614-51T)
# Acer Predator 15 (G9-592)
# ASUS R540YA
# Acer ASPIRE E5-573G-57C2
# Lenovo IdeaPad 300 17
# MSI GS70 2PC Stealth
# ASUS R541NA
# DELL XPS 13 9365 2-in-1
# Acer Predator Helios 500 (PH517-61)
# ASUS N551JB
# ASUS K501UX
# MSI GL62M 7RDX
# HP ProBook 650 G2
# ASUS VivoBook F441BA
# ASUS ZenBook Pro UX550VE
# MSI Creator 15M A9SD
# MSI P65 Creator 9SE
# HP Spectre 13-4100 x360
# DIGMA EVE 605
# ASUS K556UQ
# Lenovo Yoga 720 15
# MSI GE73 8RF Raider RGB
# Acer SWIFT 3 (SF514-54GT)
# DELL INSPIRON 7373
# Lenovo ThinkPad 13 Ultrabook
# Acer ASPIRE 3 (A315-31)
# DELL LATITUDE D430
# ASUS ZenBook S UX391FA
# AORUS X9
# Acer ASPIRE E5-573G-37M5
# HP Chromebook 14 G5
# HP Envy 17-ce0000
# Acer Predator 17X (GX-792)
# Acer TravelMate P4 (TMP449-G3-MG)
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=20&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=21&onstock=1&local-offers-first=0
# 21 48
# MSI GS73 8RE Stealth
# ASUS ZENBOOK UX303UA
# MSI GT76 Titan DT 9SG
# MSI GP63 8RE Leopard
# DELL Latitude 5400
# Acer ASPIRE E5-573-C68M
# Lenovo THINKPAD X1
# MSI GV62VR 7RF
# MSI GF62 8RE
# ASUS K751
# HP EliteBook 745 G6
# MSI GF72 8RE
# MSI GL72 6QD
# DELL LATITUDE E4310
# Acer SPIN 7 (SP714-51)
# MSI GT75 8RG Titan
# Acer ASPIRE E5-573G-312U
# ASUS VivoBook A540LA
# ASUS ROG G751JL
# MSI GE63 8RF Raider RGB
# ASUS F553SA
# ASUS ROG Zephyrus GX501GI
# ASUS VivoBook A712
# Acer ASPIRE E5-573-P42K
# ASUS ROG G501VW
# MSI GT73VR 6RE Titan
# ASUS X751SJ
# DELL LATITUDE 7280
# Xiaomi Mi Laptop Air 13.3"
# Acer ASPIRE E5-573G-380H
# MSI Creator 15M A9SE
# DELL PRECISION 3530
# Lenovo G50-80
# Acer Predator Helios 500 (PH517-51)
# Lenovo Yoga 900s
# HP PAVILION 15-bk100 x360
# DELL PRECISION 7530
# HP OMEN 15-dh0000
# HP ZBook 15 G6
# ASUS ZenBook 3 UX390UA
# MSI GT73EVR 7RE Titan
# MSI GT63 Titan 8RF
# ASUS ROG GL702VM
# Lenovo B51-80
# MSI P65 Creator 9SD
# MSI GS75 Stealth 9SG
# DELL XPS 15 9550
# MSI GE75 Raider 9SE
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=21&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=22&onstock=1&local-offers-first=0
# 22 48
# Lenovo Flex 4 15
# MSI GP73 8RE Leopard
# Lenovo Ideapad 330-14 Intel
# ASUS Transformer Book Flip TP300LA
# DELL PRECISION 7730
# Lenovo ThinkPad E15
# ASUS VivoBook 17 F705UA
# MSI GT73EVR 7RF Titan Pro
# HP EliteBook 850 G4
# Lenovo THINKPAD X1 Carbon Ultrabook (6th Gen)
# Microsoft Surface Book
# Lenovo Legion Y730-15
# ASUS ZenBook Flip UX360CA
# Acer TravelMate P6 (TMP648-G3-M)
# Lenovo ThinkPad P52
# MSI GE75 8SG Raider
# HP ProBook 455 G5
# Alienware 15 R3
# HP EliteBook 1050 G1
# Acer ASPIRE E5-573G-58NE
# HP EliteBook 735 G5
# MSI WS75 9TL
# Acer ASPIRE E5-573G-31M5
# HP EliteBook 840 G5
# Acer ASPIRE E5-573G-58E1
# Acer ASPIRE E5-575-325R
# MSI GE75 Raider 8RF
# Acer Extensa 2508-P4P3
# Lenovo ThinkPad L13
# HP ProBook 455 G4
# MSI GL73 8SC
# MSI GV72 8RD
# Acer ASPIRE E5-571G-31VE
# Lenovo THINKPAD T470p
# Lenovo THINKPAD Edge 15 Intel
# MSI GL75 9SEK
# HP Envy 13-aq1000
# ASUS R702
# Lenovo THINKPAD L570
# HP 15-ba100
# HP ZBook 15
# Acer ASPIRE E5-573-37JN
# ASUS Zenbook Flip RX562FD
# HP ProBook 650 G4
# Acer ASPIRE E5-573G-598B
# HP PAVILION DV7-6b00
# Acer TravelMate P2 (TMP278-MG)
# DELL LATITUDE 110L
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=22&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=23&onstock=1&local-offers-first=0
# 23 48
# HP nc4400
# HP PAVILION g7-1100
# Acer Aspire 7 (A715-73G)
# ASUS K52DY
# Fujitsu LIFEBOOK S938
# ASUS ROG GL704
# Acer ASPIRE E5-521-42HT
# Lenovo ThinkPad X1 Yoga (3rd Gen)
# DELL LATITUDE 7290
# MSI GE75 8SE Raider
# HP ZBook 14u G6
# Lenovo IdeaPad Flex 2 Pro
# ASUS ROG G752VY
# Acer Extensa EX2511
# HP ZBook 17 G6
# Panasonic TOUGHBOOK CF-52
# Acer ASPIRE ES1-521-26UW
# MSI WT75 8SM
# Lenovo Yoga 500 15
# MSI P75 Creator 9SD
# Apple MacBook Early 2016
# Lenovo ThinkPad L13 Yoga
# MSI GP65 Leopard 9SE
# Lenovo ThinkPad T490s
# DELL Precision 3540
# Alienware 15
# ASUS X751NV
# ASUS VivoBook Pro M580GD
# ASUS ZenBook 15 UX533
# Acer ASPIRE E5-573G-37HW
# Acer ASPIRE E5-573G-35VR
# MSI PL60 7RD
# ASUS ZenBook 3 Deluxe UX490UA
# Acer SWIFT 3 (SF314-55G)
# Lenovo Yoga 500 14
# HP PAVILION 17-ab200
onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=29&onstock=1&local-offers-first=0
# 29 48
# Acer ASPIRE E5-772G-32DL
# MSI GE62VR 7RF Camo Squad Limited Edition
# MSI GP72 2QE Leopard Pro
# Sony VAIO VPC-X11Z1R
# HP Spectre Pro x360 G1
# ASUS ROG STRIX SCAR II GL564
# Fujitsu LIFEBOOK S937
# MSI WS63 8SJ
# ASUS ROG Zephyrus GX501VS
# ASUS Zenbook 13 BX333
# MSI GL73 9SDK
# MSI GE63VR 7RE RAIDER
# MSI WE73 8SJ
# DELL INSPIRON M5110
# MSI WE63 8SJ
# MSI GT73VR 6RE Titan SLI
# HP ProBook 645 G2
# MSI WS63 8SK
# Acer ASPIRE R5-471T-52ES
# Lenovo IdeaPad Y500
# MSI WT75 9SK
# MSI PE60 6QD
# MSI WE63 8SI
# MSI GS73 8RF Stealth
# MSI GT75 Titan 8SG
# MSI WT73VR 7RM
# MSI GV72 8RE
# Sony VAIO Fit A SVF14N1J2R
# MSI WE73 8SK
# MSI WS63 8SL
# MSI WT75 8SL
# MSI GE62VR 7RF Apache Pro
# Sony VAIO VPC-F21Z1R
# MSI PE62 8RC
# MSI WS63 7RK
# HP EliteBook 6930p
# HP EliteBook 2540p
# Lenovo IdeaPad Z585
# Lenovo THINKPAD T430s
# Sony VAIO Pro SVP1322M1R
# Sony VAIO SVS1312E3R
# Sony VAIO Duo 11 SVD1121Z9R
# HP EliteBook 8540p
# Sony VAIO Fit A SVF15N2Z2R
# Sony VAIO Fit A SVF15N1Z2R
# Lenovo THINKPAD L412
# Sony VAIO SVS1512X1R
# Sony VAIO SVS1312S9R
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=29&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=30&onstock=1&local-offers-first=0
# 30 48
# Sony VAIO SVS1311M9R
# Sony VAIO VPC-EB2E9R
# Sony VAIO VPC-SA2Z9R
# Sony VAIO VPC-SB2Z9R
# Sony VAIO SVE1713P1R
# Alienware 13 R2
# Sony VAIO Fit A SVF14N1E4R
# Sony VAIO SVS1311S9R
# Sony VAIO VPC-SA4S9R
# Sony VAIO SVS1312M9R
# Sony VAIO Fit A SVF14N1D4R
# Acer ASPIRE 3 (A315-54K-34WJ) (Intel Core i3 7020U 2300 MHz/15.6"/1366x768/4GB/128GB SSD/DVD нет/Intel HD Graphics 620/Wi-Fi/Bluetooth/Windows 10 Home)
# Acer ASPIRE 3 (A315-54K-35FA) (Intel Core i3 7020U 2300 MHz/15.6"/1366x768/4GB/256GB SSD/DVD нет/Intel HD Graphics 620/Wi-Fi/Bluetooth/Linux)
# Lenovo Ideapad L340-17API AMD (AMD Ryzen 3 3200U 2600 MHz/17.3"/1600x900/4GB/500GB HDD/DVD/CD-RW/AMD Radeon Vega 3 /Wi-Fi/Bluetooth/DOS)
# Acer Aspire 3 (A315-42G-R9XV) (AMD Ryzen 7 3700U 2300 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/AMD Radeon 540X 2GB/Wi-Fi/Bluetooth/Linux)
# Apple MacBook Air 13 Mid 2017 (Intel Core i5 1800 MHz/13.3"/1440x900/8Gb/128Gb SSD/DVD нет/Intel HD Graphics 6000/Wi-Fi/Bluetooth/MacOS X)
# Xiaomi Mi Notebook Air 13.3" 2019 (Intel Core i5 8250U 1600 MHz/13.3"/1920x1080/8GB/256GB SSD/DVD нет/NVIDIA GeForce MX250/Wi-Fi/Bluetooth/Windows 10 Home)
# Apple MacBook Pro 16 with Retina display and Touch Bar Late 2019 (Intel Core i9 2300 MHz/16"/3072x1920/16GB/1024GB SSD/DVD нет/AMD Radeon Pro 5500M 4GB/Wi-Fi/Bluetooth/macOS)
# ASUS VivoBook F512DA-EJ198T (AMD Ryzen 5 3500U 2100 MHz/15.6"/1920x1080/6GB/1000GB HDD/DVD нет/AMD Radeon Vega 8/Wi-Fi/Bluetooth/DOS)
# Acer Extensa 15 EX215-51 (Intel Core i3 10110U 2100 MHz/15.6"/1920x1080/4GB/256GB SSD/DVD нет/Intel UHD Graphics 620 null/Wi-Fi/Bluetooth/Windows 10 Home)
# Lenovo IdeaPad S340-15API (AMD Ryzen 3 3200U 2600 MHz/15.6"/1920x1080/4GB/256GB SSD/DVD нет/AMD Radeon Vega 3/Wi-Fi/Bluetooth/DOS)
# ASUS VivoBook 15 X512UA-BQ448T (Intel Core i3 7020U 2300 MHz/15.6"/1920x1080/4GB/256GB SSD/DVD нет/Intel HD Graphics 620 null/Wi-Fi/Bluetooth/Windows 10 Home)
# Apple MacBook Pro 16 with Retina display and Touch Bar Late 2019 (Intel Core i7 2600 MHz/16"/3072x1920/16GB/512GB SSD/DVD нет/AMD Radeon Pro 5300M 4GB/Wi-Fi/Bluetooth/macOS)
# ASUS VivoBook 15 X512DK-BQ069T (AMD Ryzen 3 2200U 2500 MHz/15.6"/1920x1080/4GB/500GB HDD/DVD нет/AMD Radeon 540X/Wi-Fi/Bluetooth/Windows 10 Home)
# Xiaomi Mi Notebook Air 13.3" 2019 (Intel Core i7 8550U 1800 MHz/13.3"/1920x1080/8GB/512GB SSD/DVD нет/NVIDIA GeForce MX250 2GB/Wi-Fi/Bluetooth/Windows 10 Home)
# DELL Inspiron 3780 (Intel Core i5 8265U 1600 MHz/17.3"/1920x1080/8GB/1128GB HDD+SSD/DVD-RW/AMD Radeon 520/Wi-Fi/Bluetooth/Linux)
# Lenovo Ideapad S340-15API (AMD Ryzen 5 3500U 2100 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/AMD Radeon Vega 8/Wi-Fi/Bluetooth/DOS)
# Lenovo IdeaPad S340-15 AMD (AMD Ryzen 5 3500U 2100 MHz/15.6"/1920x1080/8GB/1128GB HDD+SSD/DVD нет/AMD Radeon Vega 8/Wi-Fi/Bluetooth/DOS)
# Lenovo Ideapad L340-17IWL (Intel Pentium 5405U 2300 MHz/17.3"/1920x1080/8GB/1000GB HDD/DVD нет/Intel UHD Graphics 620/Wi-Fi/Bluetooth/DOS)
# Lenovo IdeaPad S340-15 Intel (Intel Core i3 8145U 2100 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/Intel UHD Graphics 620/Wi-Fi/Bluetooth/DOS)
# ASUS VivoBook 15 X512UA-BQ528T (Intel Core i3 7020U 2300 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/Intel HD Graphics 620 null/Wi-Fi/Bluetooth/Windows 10 Home)
# Lenovo Ideapad L340-15 AMD (AMD Ryzen 5 3500U 2100 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/AMD Radeon Vega 8/Wi-Fi/Bluetooth/DOS)
# Lenovo Ideapad L340-15API (AMD Ryzen 3 3200U 2600 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/AMD Radeon Vega 3/Wi-Fi/Bluetooth/DOS)
# Lenovo V130-15IKB (Intel Pentium 4417U 2300 MHz/15.6"/1920x1080/4GB/128GB SSD/DVD-RW/Intel HD Graphics 610 null/Wi-Fi/Bluetooth/DOS)
# ASUS TUF Gaming FX505DT-AL115 (AMD Ryzen 5 3550H 2100 MHz/15.6"/1920x1080/8GB/1000GB HDD/DVD нет/NVIDIA GeForce GTX 1650/Wi-Fi/Bluetooth/DOS)
# Acer ASPIRE 3 (A315-22-686C) (AMD A6 9220e 1600 MHz/15.6"/1920x1080/4GB/256GB SSD/DVD нет/AMD Radeon R4 /Wi-Fi/Bluetooth/Windows 10 Home)
# DELL Inspiron 3584 (Intel Core i3 7020U 2300 MHz/15.6"/1920x1080/4GB/256GB SSD/DVD нет/Intel HD Graphics 620/Wi-Fi/Bluetooth/Linux)
# Lenovo IdeaPad S340-14IWL (Intel Pentium 5405U 2300 MHz/14"/1920x1080/8GB/256GB SSD/DVD нет/Intel UHD Graphics 610/Wi-Fi/Bluetooth/DOS)
# DELL Inspiron 3584 (Intel Core i3 7020U 2300 MHz/15.6"/1920x1080/4GB/128GB SSD/DVD нет/Intel HD Graphics 620/Wi-Fi/Bluetooth/Windows 10 Home)
# DELL Vostro 3584-4417 (Intel Core i3 7020U 2300 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/Intel UHD Graphics 620/Wi-Fi/Bluetooth/Linux)
# Acer SWIFT 3 (SF314-52-39JT) (Intel Core i3 7100U 2400 MHz/14"/1920x1080/4Gb/256Gb SSD/DVD нет/Intel HD Graphics 620/Wi-Fi/Bluetooth/Windows 10 Home)
# Lenovo IdeaPad S340-14IWL (Intel Pentium 5405U 2300 MHz/14"/1920x1080/4GB/128GB SSD/DVD нет/Intel UHD Graphics 610/Wi-Fi/Bluetooth/DOS)
# HP 14-dk0003ur (AMD Ryzen 3 3200U 2600 MHz/14"/1920x1080/4GB/128GB SSD/DVD нет/AMD Radeon Vega 3/Wi-Fi/Bluetooth/Windows 10 Home)
# Lenovo ThinkPad T590 (Intel Core i7 8565U 1800 MHz/15.6"/3840x2160/16GB/512GB SSD/DVD нет/NVIDIA GeForce MX250 2GB/Wi-Fi/Bluetooth/3G/LTE/Windows 10 Pro)
# HP 15-db1044ur (AMD Ryzen 3 3200U 2600 MHz/15.6"/1920x1080/8GB/256GB SSD/DVD нет/AMD Radeon Vega 3/Wi-Fi/Bluetooth/Windows 10 Home)
# Lenovo IdeaPad S340-14IWL (Intel Core i3 8145U 2100 MHz/14"/1920x1080/4GB/256GB SSD/DVD нет/Intel UHD Graphics 620/Wi-Fi/Bluetooth/DOS)
# HP 14-dk0018ur (AMD Athlon 300U 2400 MHz/14"/1366x768/4GB/128GB SSD/DVD нет/AMD Radeon Vega 3/Wi-Fi/Bluetooth/Windows 10 Home)
# ASUS X507UA-EJ1148 (Intel Pentium 4417U 2300 MHz/15.6"/1920x1080/4Gb/128GB SSD/DVD нет/Intel UHD Graphics 620/Wi-Fi/Bluetooth/Endless OS)
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=30&onstock=1&local-offers-first=0
# поехали  https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=31&onstock=1&local-offers-first=0
# 31 48
# Lenovo Ideapad L340-15IWL (Intel Celeron 4205U 1800 MHz/15.6"/1920x1080/4GB/128GB SSD/DVD нет/Intel UHD Graphics 610/Wi-Fi/Bluetooth/DOS)
# DELL Inspiron 3780 (Intel Core i5 8265U 1600 MHz/17.3"/1920x1080/8GB/1128GB HDD+SSD/DVD-RW/AMD Radeon 520/Wi-Fi/Bluetooth/Windows 10 Home)
# DELL Inspiron 3582 (Intel Pentium N5000 1100 MHz/15.6"/1920x1080/4GB/128GB SSD/DVD нет/Intel UHD Graphics 605/Wi-Fi/Bluetooth/Linux)
# Xiaomi RedmiBook 14" (Intel Core i7 8565U 1800 MHz/14"/1920x1080/8GB/512GB SSD/DVD нет/NVIDIA GeForce MX250 2GB/Wi-Fi/Bluetooth/Windows 10 Home)
# HP
# ASUS ZenBook 13 UX333FA-A4011T (Intel Core i5 8265U 1600 MHz/13.3"/1920x1080/8GB/256GB SSD/DVD нет/Intel UHD Graphics 620 null/Wi-Fi/Bluetooth/Windows 10 Home)
# https://market.yandex.ru/catalog--noutbuki/54544/list?hid=91013&page=50&onstock=1&local-offers-first=0
# облом...  404
# 2400
# 2045

# %%
#парсим цены
#'Name' - название модели оно же является внешними ключем к df
#'Quantaty' - число цен на странице модели
#'MinPrice','AvgPrice','MaxPrice' - цены. 


import requests
from bs4 import BeautifulSoup 
import time
import pandas as pd
from datetime import datetime
import random
import pdb
from urllib.parse   import quote


app_count = False

def cookies():
    
    cookies = {
            'yandexuid' : '1316442951370867155', 
            'fuid01' : '4f310da92e0e9ff0.vHkMwDo78qH5TTmHx-stTeCpjL9q0oCG-kHm-t1yw00rSnf7Uxj5eqXaFjpO-Ji3kSQu-TbS-duDcL4tBTDDknJm0Xp2PwtEYgzI74M0t3XEplZr69TXugVdbykMuUYo; yp=1571397397.shlos.0#1600341397.p_sw.1568805397#1572440968.ygu.1#1585616974.szm.1:1680x1050:1614x887', 
            '_ym_uid' : '1478001885185024594',
            'i' : '8k0m5URcQTs/D8+3VhGAv5WDga2dnppzBVV1QJC90LIBHvPMRGJZCfTnVJ0n+Mn0B1Jzd5hn+0ZsECAkAdHOR+LT58Y=',
            'mda':'0', 
            'my' : 'YwA=', 
            'yabs' : '-frequency=/4/0000000000000000/XtroS9mt81g-FMsSDoUqLB1md3SW/', 
            '_ym_isad' : '=2', 
            'yandex_gid' : '213', 
            'font_loaded' : 'YSv1', 
            '_ym_wasSynced' : '%7B%22time%22%3A1569848959698%2C%22params%22%3A%7B%22eu%22%3A0%7D%2C%22bkParams%22%3A%7B%7D%7D', 
            '_ym_d' : '1569848960', 
            '_ym_visorc_160656':'b', 
            '_ym_visorc_45411513':'b', 
            'markethistory':'<h><cm>6427101-9238862</cm><cm>6427101-8538765</cm><m>106905-10467479</m><m>432460-7691987</m><c>7156311</c></h>', 
            'cmp-merge':'true', 
            'reviews-merge':'true', 
            'head-banner-sovetnik':'%7B%22closingCounter%22%3A0%2C%22showingCounter%22%3A1%2C%22shownAfterClicked%22%3Afalse%2C%22isClicked%22%3Afalse%7D; head-banner-sovetnik-info=%7B%22closingCounter%22%3A0%2C%22showingCounter%22%3A1%2C%22shownAfterClicked%22%3Afalse%2C%22isClicked%22%3Afalse%7D', 
            'head-banner':'%7B%22closingCounter%22%3A0%2C%22showingCounter%22%3A526%2C%22shownAfterClicked%22%3Afalse%2C%22isClicked%22%3Afalse%7D; currentRegionId=213', 
            'currentRegionName':'%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D1%83', 
            'pof':'%7B%22clid%22%3A%5B%22505%22%5D%2C%22mclid%22%3Anull%2C%22distr_type%22%3Anull%2C%22vid%22%3Anull%2C%22opp%22%3Anull%7D', 
            'cpa':'%7B%22clid%22%3A%5B%22505%22%5D%2C%22mclid%22%3Anull%2C%22distr_type%22%3Anull%2C%22vid%22%3Anull%2C%22opp%22%3Anull%7D; visits=1569848974-1569848974-1569848974; parent_reqid_seq=d42a92a5871ff61374b913eb3f4ccf8f%2Cce5b53e8a009fae941bde9127ffccf95%2C07c761fd008a9de5656c84921bf0aa02; utm_campaign=face_abovesearch', 
            'utm_source' : 'face_abovesearch', 
            'uid':'AABbhl2R/o6riwEABZ1KAg==', 
            'js':'1', 
            'first_visit_time' : '2019-09-30T16%3A09%3A25%2B03%3A00', 
            'HISTORY_UNAUTH_SESSION':'true', 
            'fonts-loaded':'1', 
            'ugcp':'1'
            }   
    
    return cookies

def header(referer):
   
    header = dict()
#    header['Referer'] = 'https://market.yandex.ru/search' + '?text=' + quote(referer) + '&onstock=1&local-offers-first=0'
    header['Referer'] = quote(referer)
    header['Accept'] = 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3'
    header['Accept-Encoding']: 'gzip, deflate, br'
    header['Accept-Language'] = 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7'
    header['Connection'] = 'keep-alive'
    header['Sec-Fetch-Mode']: 'navigate'
    header['Sec-Fetch-Site']: 'same-origin'
    header['Sec-Fetch-User:']:'?1'
    header['Upgrade-Insecure-Requests']: '1'
    header['User-Agent']: 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
    
    return header

def proxies(count):
    
    return ip_port

def offers_prices_harvest(offers_href, ref_href, offers_q):
#Забор списка цен из предложений    
    pages = (offers_q // 10) + 1
    page = 1
    
    prices_list = list()
    
    page_href = offers_href
    new_ref_href = ref_href
    
    pages_is_ok = True
    
    while pages_is_ok == True:
        try:
            offers_response = requests.get(page_href, 
                                        headers = header(new_ref_href), 
                                        cookies = cookies())
            if offers_response.status_code == 200:
                offers_page = BeautifulSoup(offers_response.text,'html.parser')
                
                page_prices = offers_page.find_all('div', class_='price')
                print(page_prices[0], page_prices[0].text)
      
          
                page_price_list = [int(i.text.replace(' ','').replace('₽','')) for i in page_prices]
           
                
                prices_list += page_price_list
                

        except Exception as Err:
            print (Err)
        
        page += 1
        new_ref_href = page_href
        page_href = offers_href + '&page=' + str(page)
        
        if offers_page.find('a', class_='button button_size_s button_theme_pseudo n-pager__button-next i-bem n-smart-link') is None:
            pages_is_ok = False
        
    
    return prices_list  

def ttx_harvest(ttx_list, ttx_href, ref_href):
#Сбор итребуемых ТТХ    
    ttx_dict = dict()
    for i in ttx_list:
        ttx_dict[i] = ''
   
    try:
        response = requests.get(ttx_href, headers = header(ref_href), cookies = cookies())
        if response.status_code -- 200:
            page = BeautifulSoup(response.text,'html.parser')
        #вся таблица характеристик
        ttx_table = page.find('div', class_='layout__col layout__col_size_p75 n-product-spec-wrap')
        ttx_table_rows = ttx_table.find_all('dl', class_='n-product-spec')

        for dl in ttx_table_rows:
            dl_name = dl.find('span', class_='n-product-spec__name-inner').text
            if dl_name in ttx_list:
                specs_value = dl.find('span', class_='n-product-spec__value-inner').text
                #Забираем только самые полные характеристики в случае дубляжа категорий в таблице
                if len(ttx_dict[dl_name]) < len(specs_value):
                    ttx_dict[dl_name] = specs_value
    
    except Exception as Err_response:
           print (Err_response)
    
    
    return ttx_dict
    
    


def model_page_parsing_v2(model_df):
    
    global app_count
    
    if app_count:
        print(model_df['Name'])
        #pdb.set_trace()
        try:
            #byte_str = bytes(model_df['Name'],'UTF-8')
            
            response = requests.get('https://market.yandex.ru' + model_df['Href'], 
                                    headers = header('https://market.yandex.ru/search' + '?text=' + model_df['Name'] + '&onstock=1&local-offers-first=0'), 
                                    cookies = cookies())
            if response.status_code == 200:
                
                page = BeautifulSoup(response.text,'html.parser')
                title = page.find('title')
                
                if model_df['Name'] in title.text: 
                    
                    
                    #Табличка верхняя серая
                    table_grey = page.find('ul', class_='n-product-tabs__list')
                    #`Цены`
                    prices_count_cell = table_grey.find('li', class_='n-product-tabs__item n-product-tabs__item_name_offers')
                    
                    #Количство цен (предложений)
                    if prices_count_cell.find('span', class_='n-product-tabs__count') is not None:
                        model_df['Quantaty'] = int(prices_count_cell.find('span', class_='n-product-tabs__count').text)
                    else:
                        model_df['Quantaty'] = 0
                        
                    #Цены Средняя, минимум, максимум со страницы модели в боттоме
                    #Средняя _3TkwCtZtaF Мин/Макс _1S8ob0AgBK
 
                    if model_df['Quantaty'] > 2:
                        #а есть ли боттом c ценами?
                        teg_h2 = page.find_all('h2')
                        teg_h2_texts = [i.text for i in teg_h2]
                        
                        if 'Средняя цена' in teg_h2_texts:
                        
                            #margin_prices = page.find_all('div', class_='n-w-product-average-price__value') 
                            model_df['MinPrice'] = 'xxx' #int(margin_prices[0].find('span', class_='price').text.replace(' ',''))
                            model_df['MaxPrice'] = 'xxx' #int(margin_prices[1].find('span', class_='price').text.replace(' ',''))
                            avg_price = page.find('div', class_='_3TkwCtZtaF')#page.find('div', class_='n-w-product-average-price__average-value')
                            model_df['AvgPrice'] = int(avg_price.find('span').text.replace(' ','').replace('₽',''))
                        else:
                            #тыды лезем внутря в список цен, руками:
                            offers_href = 'https://market.yandex.ru' + str(prices_count_cell.find('a').get('href'))
                            ref_href = 'https://market.yandex.ru' + model_df['Href']
                            offers_price_list = pd.Series(offers_prices_harvest(offers_href, ref_href, model_df['Quantaty']))
                            model_df['AvgPrice'] = offers_price_list.mean()
                            model_df['MinPrice'] = offers_price_list.min()
                            model_df['MaxPrice'] = offers_price_list.max()
                        

                    else:
#                        model_dict['MinPrice'] = None 
#                        model_dict['MaxPrice'] = None
                        avg_price = page.find('div', class_='n-product-price-cpa2__price')
                        if avg_price is not None:
                            model_df['AvgPrice'] = int(avg_price.find('span', class_='price').text.replace(' ','').replace('₽',''))
                        else:
                            model_df['AvgPrice'] = 'na'
                    

                    #ТТХ (если список характеристик не пуст - лезем на страницу характеристик модели)
                    ttx_list = list(set(list(model_df.index)) - set(['Href', 'Vendor','Name','Quantaty','MinPrice','MaxPrice','AvgPrice']))
                    
                    if len(ttx_list) != 0:
                        try: #на случай если ссылки на характеристики нет
                            ttx_link = str(page.find('a', class_ = 'n-product-summary__spec-link n-smart-link link i-bem').get('href'))
                            
                            ttx_href = 'https://market.yandex.ru' + ttx_link
                            ref_href = 'https://market.yandex.ru' + model_df['Href']
                            
                            ttx_dict = ttx_harvest(ttx_list, ttx_href, ref_href)
                            for i in ttx_list:
                                model_df[i] = ttx_dict[i]
             
                                
                        except AttributeError as Err_ttx:
                            print(Err_ttx)

                    
                elif title.text == 'ÐÐ¹!':
                    print('Облом: капча. Пропускаем')
                    
                else:
                    print('Еще чета не так')
            else:
                print(response.status_code) 
                    
        except Exception as Err:
            print (Err)
            raise
            
 
    else:
        app_count = True  
    
    display(model_df)
    return model_df
    
def price_parsing1(df):
    
    try:

        df[df['Quantaty'].isna() == True] = df[df['Quantaty'].isna() == True].apply(model_page_parsing_v2, axis = 1)
    
    except Exception as Err:
        print(Err)
   
    return df

model_links_for_parse = pd.read_excel('Price_link_list/Ноутбук-ссылки от 2019-12-04--16-30.xlsx', index_col=0)
previous_parsing_pass = pd.read_excel('Prices/Пустая_болванка_для_цен3.xlsx', index_col=0)

fields = list(set(list(previous_parsing_pass.columns)) - set(['','Href', 'Vendor', 'Category']))

print(fields)

df_for_parse = model_links_for_parse[model_links_for_parse['Assemble'] == True][['Href','Name','Vendor', 'Category']].merge(previous_parsing_pass[fields], how = 'left', on = 'Name')

print('на вход', len(df_for_parse))
parsed_df = price_parsing1(df_for_parse)
print('на выход', len(parsed_df))

 
now = datetime.now().strftime('%d-%m-%y--%H-%M')
parsed_excel_file_name = 'Prices/' + model_links_for_parse['Category'][0] + '-Цены' + now + '.xlsx'
parsed_df.to_excel(parsed_excel_file_name)
# Out:
# ['Ядро процессора', 'MaxPrice', 'Процессор', 'Сенсорный экран', 'Quantaty', 'MinPrice', 'AvgPrice', 'Name', 'Диагональ экрана', 'Тип видеокарты', 'Видеокарта']
# на вход 1323
# Href                /product--noutbuk-asus-vivobook-15-x512/518204...
# Name                                            ASUS VivoBook 15 X512
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                                                   NaN
# MaxPrice                                                          NaN
# Процессор                                                         NaN
# Сенсорный экран                                                   NaN
# Quantaty                                                          NaN
# MinPrice                                                          NaN
# AvgPrice                                                          NaN
# Диагональ экрана                                                  NaN
# Тип видеокарты                                                    NaN
# Видеокарта                                                        NaN
# Name: 0, dtype: object
# ASUS VivoBook 15 X512
# Href                /product--noutbuk-asus-vivobook-15-x512/518204...
# Name                                            ASUS VivoBook 15 X512
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора     Kaby Lake / Kaby Lake-R / Raven Ridge / Whiske...
# MaxPrice                                                          xxx
# Процессор            Core i3 / Core i5 / Core i7 / Ryzen 3 / Ryzen 5
# Сенсорный экран                                                  нет
# Quantaty                                                          594
# MinPrice                                                          xxx
# AvgPrice                                                        39799
# Диагональ экрана                                              15.6 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта          AMD Radeon 540X / AMD Radeon Vega 3 / Intel HD...
# Name: 0, dtype: object
# Acer Extensa 15 EX215-51
# Href                /product--noutbuk-acer-extensa-15-ex215-51/601...
# Name                                         Acer Extensa 15 EX215-51
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора                          Comet Lake-U / Whiskey Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i3 / Core i5
# Сенсорный экран                                                  нет
# Quantaty                                                          784
# MinPrice                                                          xxx
# AvgPrice                                                        31160
# Диагональ экрана                                              15.6 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта          Intel HD Graphics 620, Intel UHD Graphics, Int...
# Name: 1, dtype: object
# Apple MacBook Pro 16 with Retina display and Touch Bar Late 2019
# <div class="price">221 500 ₽</div> 221 500 ₽
# <div class="price price_unactual_yes"><span class="price price_unactual_yes">224 550 ₽</span></div> 224 550 ₽
# <div class="price">232 900 ₽</div> 232 900 ₽
# <div class="price">214 990 ₽</div> 214 990 ₽
# <div class="price">239 990 ₽</div> 239 990 ₽
# Href                /product--noutbuk-apple-macbook-pro-16-with-re...
# Name                Apple MacBook Pro 16 with Retina display and T...
# Vendor                                                          Apple
# Category                                                      Ноутбук
# Ядро процессора
# MaxPrice                                                       239990
# Процессор                                          Core i7 / Core i9
# Сенсорный экран                                                  нет
# Quantaty                                                          138
# MinPrice                                                       171990
# AvgPrice                                                       211750
# Диагональ экрана                                                16 "
# Тип видеокарты                    встроенная, дискретная и встроенная
# Видеокарта               AMD Radeon Pro 5300M / AMD Radeon Pro 5500M
# Name: 2, dtype: object
# Xiaomi RedmiBook 14"
# Href                /product--noutbuk-xiaomi-redmibook-14/53865400...
# Name                                             Xiaomi RedmiBook 14"
# Vendor                                                         Xiaomi
# Category                                                      Ноутбук
# Ядро процессора                        Whiskey Lake / Whiskey Lake-U
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           66
# MinPrice                                                          xxx
# AvgPrice                                                        47890
# Диагональ экрана                                                14 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта               Intel UHD Graphics 620, NVIDIA GeForce MX250
# Name: 3, dtype: object
# DELL Vostro 5590
# Href                /product--noutbuk-dell-vostro-5590/597180017?s...
# Name                                                 DELL Vostro 5590
# Vendor                                                           DELL
# Category                                                      Ноутбук
# Ядро процессора                                         Comet Lake-U
# MaxPrice                                                          xxx
# Процессор                                            Core i5, Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           46
# MinPrice                                                          xxx
# AvgPrice                                                        56390
# Диагональ экрана                                              15.6 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта          Intel UHD Graphics, Intel UHD Graphics 620, NV...
# Name: 4, dtype: object
# Lenovo IdeaPad S340-15 AMD
# Href                /product--noutbuk-lenovo-ideapad-s340-15-amd/5...
# Name                                       Lenovo IdeaPad S340-15 AMD
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора                                                  Zen
# MaxPrice                                                          xxx
# Процессор                 Core i3, Core i5, Core i7, Ryzen 3, Ryzen 5
# Сенсорный экран                                                  нет
# Quantaty                                                          138
# MinPrice                                                          xxx
# AvgPrice                                                        41776
# Диагональ экрана                                              15.6 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта          Intel UHD Graphics, Intel UHD Graphics 620, NV...
# Name: 5, dtype: object
# ASUS TUF Gaming FX505
# Href                /product--noutbuk-asus-tuf-gaming-fx505/418966...
# Name                                            ASUS TUF Gaming FX505
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                    Coffee Lake / Coffee Lake-H / Zen
# MaxPrice                                                          xxx
# Процессор             Core i3, Core i5, Core i7, FX, Ryzen 5, Ryzen 7
# Сенсорный экран                                                  нет
# Quantaty                                                          677
# MinPrice                                                          xxx
# AvgPrice                                                        67310
# Диагональ экрана                                              15.6 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта          AMD Radeon RX 560X / NVIDIA GeForce GTX 1050 /...
# Name: 6, dtype: object
# Lenovo Ideapad L340-15 Intel
# Href                /product--noutbuk-lenovo-ideapad-l340-15-intel...
# Name                                     Lenovo Ideapad L340-15 Intel
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора     Coffee Lake / Whiskey Lake / Whiskey Lake-U / ...
# MaxPrice                                                          xxx
# Процессор           Athlon / Celeron / Core i3 / Core i5 / Pentium...
# Сенсорный экран                                                  нет
# Quantaty                                                          613
# MinPrice                                                          xxx
# AvgPrice                                                        23858
# Диагональ экрана                                              15.6 "
# Тип видеокарты                  встроенная / дискретная и встроенная
# Видеокарта          AMD Radeon Vega 3 / AMD Radeon Vega 8 / Intel ...
# Name: 7, dtype: object
# Lenovo V130 15
# Href                /product--noutbuk-lenovo-v130-15/197642238?sho...
# Name                                                   Lenovo V130 15
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора     Gemini Lake / Kaby Lake / Kaby Lake Refresh / ...
# MaxPrice                                                          xxx
# Процессор                 Celeron, Core i3, Core i5, Core i7, Pentium
# Сенсорный экран                                                  нет
# Quantaty                                                          441
# MinPrice                                                          xxx
# AvgPrice                                                        26072
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                            встроенная
# Видеокарта          AMD Radeon 530 / Intel HD Graphics 520 / Intel...
# Name: 8, dtype: object
# Acer ASPIRE 3 (A315-21)
# Href                /product--noutbuk-acer-aspire-3-a315-21/180048...
# Name                                          Acer ASPIRE 3 (A315-21)
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора                           Raven Ridge / Stoney Ridge
# MaxPrice                                                          xxx
# Процессор                                A4 / A6 / A9 / E2 / Ryzen 3
# Сенсорный экран                                                  нет
# Quantaty                                                          495
# MinPrice                                                          xxx
# AvgPrice                                                        19030
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                            встроенная
# Видеокарта          AMD Radeon R2 / AMD Radeon R3 / AMD Radeon R4 ...
# Name: 9, dtype: object
# Lenovo Ideapad 330 15 Intel
# Href                /product--noutbuk-lenovo-ideapad-330-15-intel/...
# Name                                      Lenovo Ideapad 330 15 Intel
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора     Coffee Lake / Coffee Lake-H / Gemini Lake / Ka...
# MaxPrice                                                          xxx
# Процессор            Celeron / Core i3 / Core i5 / Core i7 / Pentium
# Сенсорный экран                                                  нет
# Quantaty                                                          554
# MinPrice                                                          xxx
# AvgPrice                                                        34905
# Диагональ экрана                                              15.6 "
# Тип видеокарты      встроенная / дискретная / дискретная и встроен...
# Видеокарта          AMD Radeon 530 / Intel HD Graphics 520 / Intel...
# Name: 10, dtype: object
# Apple MacBook Pro 13 with Retina display and Touch Bar Mid 2019
# Href                /product--noutbuk-apple-macbook-pro-13-with-re...
# Name                Apple MacBook Pro 13 with Retina display and T...
# Vendor                                                          Apple
# Category                                                      Ноутбук
# Ядро процессора
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          406
# MinPrice                                                          xxx
# AvgPrice                                                       122190
# Диагональ экрана                                              13.3 "
# Тип видеокарты                                            встроенная
# Видеокарта          Intel Iris Plus Graphics 645 / Intel Iris Plus...
# Name: 11, dtype: object
# ASUS ZenBook 14 UX433
# Href                /product--noutbuk-asus-zenbook-14-ux433/273011...
# Name                                            ASUS ZenBook 14 UX433
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                        Whiskey Lake / Whiskey Lake-U
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           58
# MinPrice                                                          xxx
# AvgPrice                                                        67990
# Диагональ экрана                                                14 "
# Тип видеокарты                  встроенная / дискретная и встроенная
# Видеокарта             Intel UHD Graphics 620 / NVIDIA GeForce MX150
# Name: 12, dtype: object
# Xiaomi Mi Notebook Pro 15.6 2019
# Href                /product--noutbuk-xiaomi-mi-notebook-pro-15-6-...
# Name                                 Xiaomi Mi Notebook Pro 15.6 2019
# Vendor                                                         Xiaomi
# Category                                                      Ноутбук
# Ядро процессора                                          Kaby Lake-R
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           41
# MinPrice                                                          xxx
# AvgPrice                                                        64990
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                            дискретная
# Видеокарта                                      NVIDIA GeForce MX250
# Name: 13, dtype: object
# HP ProBook 430 G6
# Href                /product--noutbuk-hp-probook-430-g6/318549883?...
# Name                                                HP ProBook 430 G6
# Vendor                                                             HP
# Category                                                      Ноутбук
# Ядро процессора                        Whiskey Lake / Whiskey Lake-U
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          418
# MinPrice                                                          xxx
# AvgPrice                                                        51190
# Диагональ экрана                                              13.3 "
# Тип видеокарты                                            встроенная
# Видеокарта                                    Intel UHD Graphics 620
# Name: 14, dtype: object
# HP 250 G7
# Href                /product--noutbuk-hp-250-g7/439496324?show-uid...
# Name                                                        HP 250 G7
# Vendor                                                             HP
# Category                                                      Ноутбук
# Ядро процессора     Gemini Lake / Kaby Lake / Kaby Lake Refresh / ...
# MaxPrice                                                          xxx
# Процессор            Celeron / Core i3 / Core i5 / Core i7 / Pentium
# Сенсорный экран                                                  нет
# Quantaty                                                          617
# MinPrice                                                          xxx
# AvgPrice                                                        36128
# Диагональ экрана                                              15.6 "
# Тип видеокарты      встроенная / дискретная / дискретная и встроен...
# Видеокарта          Intel HD Graphics 610 / Intel HD Graphics 620 ...
# Name: 15, dtype: object
# HP ProBook 440 G6
# Href                /product--noutbuk-hp-probook-440-g6/323146560?...
# Name                                                HP ProBook 440 G6
# Vendor                                                             HP
# Category                                                      Ноутбук
# Ядро процессора                        Whiskey Lake / Whiskey Lake-U
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          431
# MinPrice                                                          xxx
# AvgPrice                                                        52905
# Диагональ экрана                                                14 "
# Тип видеокарты                  встроенная / дискретная и встроенная
# Видеокарта             Intel UHD Graphics 620 / NVIDIA GeForce MX130
# Name: 16, dtype: object
# ASUS VivoBook S15 S530
# Href                /product--noutbuk-asus-vivobook-s15-s530/19538...
# Name                                           ASUS VivoBook S15 S530
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора               Kaby Lake / Kaby Lake-R / Whiskey Lake
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           91
# MinPrice                                                          xxx
# AvgPrice                                                        55544
# Диагональ экрана                                              15.6 "
# Тип видеокарты      встроенная / дискретная / дискретная и встроен...
# Видеокарта          Intel UHD Graphics 620 / NVIDIA GeForce MX130 ...
# Name: 17, dtype: object
# HP ProBook 450 G6
# Href                /product--noutbuk-hp-probook-450-g6/308389979?...
# Name                                                HP ProBook 450 G6
# Vendor                                                             HP
# Category                                                      Ноутбук
# Ядро процессора
# MaxPrice                                                          xxx
# Процессор                                                    Core i5
# Сенсорный экран                                                  нет
# Quantaty                                                          495
# MinPrice                                                          xxx
# AvgPrice                                                        55670
# Диагональ экрана                                              15.6 "
# Тип видеокарты
# Видеокарта
# Name: 18, dtype: object
# ASUS ZenBook Duo UX481
# Href                /product--noutbuk-asus-zenbook-duo-ux481/56209...
# Name                                           ASUS ZenBook Duo UX481
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                                         Comet Lake-U
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           82
# MinPrice                                                          xxx
# AvgPrice                                                        92890
# Диагональ экрана                                                14 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта                   Intel UHD Graphics, NVIDIA GeForce MX250
# Name: 19, dtype: object
# Xiaomi Mi Notebook Air 13.3" 2019
# Href                /product--noutbuk-xiaomi-mi-notebook-air-13-3-...
# Name                                Xiaomi Mi Notebook Air 13.3" 2019
# Vendor                                                         Xiaomi
# Category                                                      Ноутбук
# Ядро процессора                                          Kaby Lake-R
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           68
# MinPrice                                                          xxx
# AvgPrice                                                        57830
# Диагональ экрана                                              13.3 "
# Тип видеокарты                  встроенная / дискретная и встроенная
# Видеокарта             Intel UHD Graphics 620 / NVIDIA GeForce MX250
# Name: 20, dtype: object
# Lenovo Ideapad L340 (15) Gaming
# Href                /product--noutbuk-lenovo-ideapad-l340-15-gamin...
# Name                                  Lenovo Ideapad L340 (15) Gaming
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора                                          Coffee Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          142
# MinPrice                                                          xxx
# AvgPrice                                                        62886
# Диагональ экрана                                              15.6 "
# Тип видеокарты                    дискретная, дискретная и встроенная
# Видеокарта          NVIDIA GeForce GTX 1050 / NVIDIA GeForce GTX 1...
# Name: 21, dtype: object
# Acer ASPIRE 3 (A315-54K)
# Href                /product--noutbuk-acer-aspire-3-a315-54k/56208...
# Name                                         Acer ASPIRE 3 (A315-54K)
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора                                            Kaby Lake
# MaxPrice                                                          xxx
# Процессор                                                    Core i3
# Сенсорный экран                                                  нет
# Quantaty                                                          161
# MinPrice                                                          xxx
# AvgPrice                                                        25820
# Диагональ экрана                                              15.6 "
# Тип видеокарты                    встроенная, дискретная и встроенная
# Видеокарта                                     Intel HD Graphics 620
# Name: 22, dtype: object
# MSI GL65 9SDK
# Href                /product--noutbuk-msi-gl65-9sdk/604943001?show...
# Name                                                    MSI GL65 9SDK
# Vendor                                                            MSI
# Category                                                      Ноутбук
# Ядро процессора                                          Coffee Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          123
# MinPrice                                                          xxx
# AvgPrice                                                        84650
# Диагональ экрана                                              15.6 "
# Тип видеокарты                               дискретная и встроенная
# Видеокарта                                NVIDIA GeForce GTX 1660 Ti
# Name: 23, dtype: object
# MSI Prestige 15 A10SC
# Href                /product--noutbuk-msi-prestige-15-a10sc/604979...
# Name                                            MSI Prestige 15 A10SC
# Vendor                                                            MSI
# Category                                                      Ноутбук
# Ядро процессора                                         Comet Lake-U
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                            8
# MinPrice                                                          xxx
# AvgPrice                                                        96459
# Диагональ экрана                                              15.6 "
# Тип видеокарты                               дискретная и встроенная
# Видеокарта                                   NVIDIA GeForce GTX 1650
# Name: 24, dtype: object
# HP 250 G6
# Href                /product--noutbuk-hp-250-g6/1729354923?show-ui...
# Name                                                        HP 250 G6
# Vendor                                                             HP
# Category                                                      Ноутбук
# Ядро процессора     Apollo Lake / Braswell / Broadwell / Gemini La...
# MaxPrice                                                          xxx
# Процессор            Celeron / Core i3 / Core i5 / Core i7 / Pentium
# Сенсорный экран                                                  нет
# Quantaty                                                          405
# MinPrice                                                          xxx
# AvgPrice                                                        32540
# Диагональ экрана                                              15.6 "
# Тип видеокарты                  встроенная / дискретная и встроенная
# Видеокарта          AMD Radeon 520 / AMD Radeon R5 M430 / Intel HD...
# Name: 25, dtype: object
# ASUS VivoBook S13 S330
# Href                /product--noutbuk-asus-vivobook-s13-s330/32913...
# Name                                           ASUS VivoBook S13 S330
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора     Kaby Lake / Kaby Lake-R / Whiskey Lake / Whisk...
# MaxPrice                                                          xxx
# Процессор                                          Core i3 / Core i5
# Сенсорный экран                                                  нет
# Quantaty                                                           37
# MinPrice                                                          xxx
# AvgPrice                                                        47685
# Диагональ экрана                                              13.3 "
# Тип видеокарты                  встроенная / дискретная и встроенная
# Видеокарта             Intel UHD Graphics 620 / NVIDIA GeForce MX150
# Name: 26, dtype: object
# Apple MacBook Air 13 дисплей Retina с технологией True Tone Mid 2019
# Href                /product--noutbuk-apple-macbook-air-13-displei...
# Name                Apple MacBook Air 13 дисплей Retina с технолог...
# Vendor                                                          Apple
# Category                                                      Ноутбук
# Ядро процессора                                         Amber Lake-Y
# MaxPrice                                                          xxx
# Процессор                                                    Core i5
# Сенсорный экран                                                  нет
# Quantaty                                                          307
# MinPrice                                                          xxx
# AvgPrice                                                        90990
# Диагональ экрана                                              13.3 "
# Тип видеокарты                                            встроенная
# Видеокарта                                    Intel UHD Graphics 617
# Name: 27, dtype: object
# DELL G5 15 5587
# Href                /product--noutbuk-dell-g5-15-5587/109750281?sh...
# Name                                                  DELL G5 15 5587
# Vendor                                                           DELL
# Category                                                      Ноутбук
# Ядро процессора
# MaxPrice                                                          xxx
# Процессор                                            Core i5, Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           38
# MinPrice                                                          xxx
# AvgPrice                                                        59199
# Диагональ экрана                                              15.6 "
# Тип видеокарты                    дискретная, дискретная и встроенная
# Видеокарта          Intel HD Graphics 630, NVIDIA GeForce GTX 1050...
# Name: 28, dtype: object
# Acer Aspire 3 (A315-42G)
# Href                /product--noutbuk-acer-aspire-3-a315-42g/56700...
# Name                                         Acer Aspire 3 (A315-42G)
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора
# MaxPrice                                                          xxx
# Процессор              Athlon, Ryzen 3, Ryzen 5, Ryzen 7, Ryzen 7 PRO
# Сенсорный экран                                                  нет
# Quantaty                                                          276
# MinPrice                                                          xxx
# AvgPrice                                                        28988
# Диагональ экрана                                              15.6 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта          AMD Radeon 540X, AMD Radeon RX 540, AMD Radeon...
# Name: 29, dtype: object
# ASUS ZenBook UX410UA
# Href                /product--noutbuk-asus-zenbook-ux410ua/1728147...
# Name                                             ASUS ZenBook UX410UA
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                              Kaby Lake / Kaby Lake-R
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           29
# MinPrice                                                          xxx
# AvgPrice                                                        47870
# Диагональ экрана                                                14 "
# Тип видеокарты                                            встроенная
# Видеокарта            Intel HD Graphics 620 / Intel UHD Graphics 620
# Name: 30, dtype: object
# MSI GF63 Thin 9RCX
# Href                /product--noutbuk-msi-gf63-thin-9rcx/562098238...
# Name                                               MSI GF63 Thin 9RCX
# Vendor                                                            MSI
# Category                                                      Ноутбук
# Ядро процессора                                          Coffee Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          111
# MinPrice                                                          xxx
# AvgPrice                                                        63470
# Диагональ экрана                                              15.6 "
# Тип видеокарты                    дискретная, дискретная и встроенная
# Видеокарта          Intel UHD Graphics 630, NVIDIA GeForce GTX 105...
# Name: 31, dtype: object
# DELL Inspiron 3584
# Href                /product--noutbuk-dell-inspiron-3584/437251104...
# Name                                               DELL Inspiron 3584
# Vendor                                                           DELL
# Category                                                      Ноутбук
# Ядро процессора                                            Kaby Lake
# MaxPrice                                                          xxx
# Процессор                                            Core i3, Core i5
# Сенсорный экран                                                  нет
# Quantaty                                                          468
# MinPrice                                                          xxx
# AvgPrice                                                        28547
# Диагональ экрана                                              15.6 "
# Тип видеокарты                               встроенная / дискретная
# Видеокарта          Intel HD Graphics 620, Intel UHD Graphics 605,...
# Name: 32, dtype: object
# Acer ASPIRE 3 (A315-41)
# Href                /product--noutbuk-acer-aspire-3-a315-41/103388...
# Name                                          Acer ASPIRE 3 (A315-41)
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора                                          Raven Ridge
# MaxPrice                                                          xxx
# Процессор                                Ryzen 3 / Ryzen 5 / Ryzen 7
# Сенсорный экран                                                  нет
# Quantaty                                                          143
# MinPrice                                                          xxx
# AvgPrice                                                        26250
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                            встроенная
# Видеокарта          AMD Radeon RX Vega 10 / AMD Radeon Vega 10 / A...
# Name: 33, dtype: object
# Lenovo V130 14
# Href                /product--noutbuk-lenovo-v130-14/197640249?sho...
# Name                                                   Lenovo V130 14
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора     Gemini Lake / Kaby Lake / Kaby Lake Refresh / ...
# MaxPrice                                                          xxx
# Процессор                      Celeron / Core i3 / Core i5 / Pentium
# Сенсорный экран                                                  нет
# Quantaty                                                          178
# MinPrice                                                          xxx
# AvgPrice                                                        30549
# Диагональ экрана                                                14 "
# Тип видеокарты                                            встроенная
# Видеокарта          Intel HD Graphics 520 / Intel HD Graphics 610 ...
# Name: 34, dtype: object
# ASUS VivoBook S14 S431
# Href                /product--noutbuk-asus-vivobook-s14-s431/61763...
# Name                                           ASUS VivoBook S14 S431
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                                         Whiskey Lake
# MaxPrice                                                          xxx
# Процессор                                            Core i3, Core i5
# Сенсорный экран
# Quantaty                                                           25
# MinPrice                                                          xxx
# AvgPrice                                                        49677
# Диагональ экрана                                                14 "
# Тип видеокарты                                            встроенная
# Видеокарта                                    Intel UHD Graphics 620
# Name: 35, dtype: object
# Xiaomi Mi Notebook Pro 15.6 GTX
# Href                /product--noutbuk-xiaomi-mi-notebook-pro-15-6-...
# Name                                  Xiaomi Mi Notebook Pro 15.6 GTX
# Vendor                                                         Xiaomi
# Category                                                      Ноутбук
# Ядро процессора                                          Kaby Lake-R
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           25
# MinPrice                                                          xxx
# AvgPrice                                                        82180
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                 встроенная, дискретная
# Видеокарта                                   NVIDIA GeForce GTX 1050
# Name: 36, dtype: object
# ASUS X507UA
# Href                /product--noutbuk-asus-x507ua/1976704061?show-...
# Name                                                      ASUS X507UA
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора            Kaby Lake / Kaby Lake Refresh / Skylake-U
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Pentium
# Сенсорный экран                                                  нет
# Quantaty                                                          100
# MinPrice                                                          xxx
# AvgPrice                                                        23490
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                            встроенная
# Видеокарта          Intel HD Graphics 520 / Intel HD Graphics 620 ...
# Name: 37, dtype: object
# Acer ASPIRE 3 (A315-22)
# Href                /product--noutbuk-acer-aspire-3-a315-22/617636...
# Name                                          Acer ASPIRE 3 (A315-22)
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора
# MaxPrice                                                          xxx
# Процессор                                                  A4, A6, A9
# Сенсорный экран                                                  нет
# Quantaty                                                           59
# MinPrice                                                          xxx
# AvgPrice                                                        19990
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                 встроенная, дискретная
# Видеокарта                              AMD Radeon 530, AMD Radeon R5
# Name: 38, dtype: object
# ASUS ZenBook 14 UX434
# Href                /product--noutbuk-asus-zenbook-14-ux434/562096...
# Name                                            ASUS ZenBook 14 UX434
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                                         Whiskey Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           19
# MinPrice                                                          xxx
# AvgPrice                                                        78275
# Диагональ экрана                                                14 "
# Тип видеокарты                    дискретная, дискретная и встроенная
# Видеокарта               Intel UHD Graphics 620, NVIDIA GeForce MX250
# Name: 39, dtype: object
# DELL XPS 15 7590
# Href                /product--noutbuk-dell-xps-15-7590/537792012?s...
# Name                                                 DELL XPS 15 7590
# Vendor                                                           DELL
# Category                                                      Ноутбук
# Ядро процессора                                          Coffee Lake
# MaxPrice                                                          xxx
# Процессор                                Core i5 / Core i7 / Core i9
# Сенсорный экран                                          опционально
# Quantaty                                                          218
# MinPrice                                                          xxx
# AvgPrice                                                       140290
# Диагональ экрана                                              15.6 "
# Тип видеокарты                    дискретная, дискретная и встроенная
# Видеокарта            Intel UHD Graphics 630, NVIDIA GeForce GTX 1650
# Name: 40, dtype: object
# Acer Extensa 15 EX215-51G
# Href                /product--noutbuk-acer-extensa-15-ex215-51g/60...
# Name                                        Acer Extensa 15 EX215-51G
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора                                         Whiskey Lake
# MaxPrice                                                          xxx
# Процессор                                            Core i3, Core i5
# Сенсорный экран                                                  нет
# Quantaty                                                          310
# MinPrice                                                          xxx
# AvgPrice                                                        35600
# Диагональ экрана                                              15.6 "
# Тип видеокарты        встроенная, дискретная, дискретная и встроенная
# Видеокарта                                      NVIDIA GeForce MX230
# Name: 41, dtype: object
# Acer Aspire 3 (A315-42)
# Href                /product--noutbuk-acer-aspire-3-a315-42/562096...
# Name                                          Acer Aspire 3 (A315-42)
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора
# MaxPrice                                                          xxx
# Процессор                           Athlon, Ryzen 3, Ryzen 5, Ryzen 7
# Сенсорный экран                                                  нет
# Quantaty                                                          557
# MinPrice                                                          xxx
# AvgPrice                                                        25615
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                 встроенная, дискретная
# Видеокарта          AMD Radeon 540X, AMD Radeon RX 540, AMD Radeon...
# Name: 42, dtype: object
# MSI GL75 9SDK
# Href                /product--noutbuk-msi-gl75-9sdk/559751021?show...
# Name                                                    MSI GL75 9SDK
# Vendor                                                            MSI
# Category                                                      Ноутбук
# Ядро процессора                                          Coffee Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           83
# MinPrice                                                          xxx
# AvgPrice                                                        86300
# Диагональ экрана                                              17.3 "
# Тип видеокарты                               дискретная и встроенная
# Видеокарта                                NVIDIA GeForce GTX 1660 Ti
# Name: 43, dtype: object
# Lenovo IdeaPad S540 15 Intel
# Href                /product--noutbuk-lenovo-ideapad-s540-15-intel...
# Name                                     Lenovo IdeaPad S540 15 Intel
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора                        Whiskey Lake / Whiskey Lake-U
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           26
# MinPrice                                                          xxx
# AvgPrice                                                        55090
# Диагональ экрана                                              15.6 "
# Тип видеокарты                  встроенная / дискретная и встроенная
# Видеокарта          Intel UHD Graphics 620 / NVIDIA GeForce GTX 16...
# Name: 44, dtype: object
# DELL Inspiron 3582
# Href                /product--noutbuk-dell-inspiron-3582/449232218...
# Name                                               DELL Inspiron 3582
# Vendor                                                           DELL
# Category                                                      Ноутбук
# Ядро процессора                                          Gemini Lake
# MaxPrice                                                          xxx
# Процессор                                 Celeron, Pentium, Pentium 4
# Сенсорный экран                                                  нет
# Quantaty                                                          572
# MinPrice                                                          xxx
# AvgPrice                                                        20421
# Диагональ экрана                                              15.6 "
# Тип видеокарты                                            встроенная
# Видеокарта           Intel UHD Graphics 600 / Intel UHD Graphics 605
# Name: 45, dtype: object
# DELL Vostro 7590
# Href                /product--noutbuk-dell-vostro-7590/498938033?s...
# Name                                                 DELL Vostro 7590
# Vendor                                                           DELL
# Category                                                      Ноутбук
# Ядро процессора                                          Coffee Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           37
# MinPrice                                                          xxx
# AvgPrice                                                        85765
# Диагональ экрана                                              15.6 "
# Тип видеокарты                    дискретная, дискретная и встроенная
# Видеокарта          NVIDIA GeForce GTX 1050 / NVIDIA GeForce GTX 1...
# Name: 46, dtype: object
# ASUS VivoBook 15 X540
# Href                /product--noutbuk-asus-vivobook-15-x540/384521...
# Name                                            ASUS VivoBook 15 X540
# Vendor                                                           ASUS
# Category                                                      Ноутбук
# Ядро процессора                  Apollo Lake / Kaby Lake / Skylake-U
# MaxPrice                                                          xxx
# Процессор                      Celeron / Core i3 / Core i5 / Pentium
# Сенсорный экран                                                  нет
# Quantaty                                                          122
# MinPrice                                                          xxx
# AvgPrice                                                        17120
# Диагональ экрана                                              15.6 "
# Тип видеокарты                               встроенная / дискретная
# Видеокарта          Intel HD Graphics 500 / Intel HD Graphics 505 ...
# Name: 47, dtype: object
# MSI Modern 14 A10M
# Href                /product--noutbuk-msi-modern-14-a10m/578384005...
# Name                                               MSI Modern 14 A10M
# Vendor                                                            MSI
# Category                                                      Ноутбук
# Ядро процессора                                         Comet Lake-U
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                           40
# MinPrice                                                          xxx
# AvgPrice                                                        59000
# Диагональ экрана                                                14 "
# Тип видеокарты                                            встроенная
# Видеокарта                                    Intel UHD Graphics 620
# Name: 48, dtype: object
# Lenovo V330 15
# Href                /product--noutbuk-lenovo-v330-15/1974946906?sh...
# Name                                                   Lenovo V330 15
# Vendor                                                         Lenovo
# Category                                                      Ноутбук
# Ядро процессора                              Kaby Lake / Kaby Lake-R
# MaxPrice                                                          xxx
# Процессор                                Core i3 / Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          243
# MinPrice                                                          xxx
# AvgPrice                                                        47641
# Диагональ экрана                                              15.6 "
# Тип видеокарты      встроенная / дискретная / дискретная и встроен...
# Видеокарта          AMD Radeon 530 / Intel HD Graphics 620 / Intel...
# Name: 49, dtype: object
# Acer Predator Helios 300 (PH315-52)
# Href                /product--noutbuk-acer-predator-helios-300-ph3...
# Name                              Acer Predator Helios 300 (PH315-52)
# Vendor                                                           Acer
# Category                                                      Ноутбук
# Ядро процессора                                          Coffee Lake
# MaxPrice                                                          xxx
# Процессор                                          Core i5 / Core i7
# Сенсорный экран                                                  нет
# Quantaty                                                          310
# MinPrice                                                          xxx
# AvgPrice                                                       110990
# Диагональ экрана                                              15.6 "
# Тип видеокарты                    дискретная, дискретная и встроенная
# Видеокарта          NVIDIA GeForce GTX 1660 Ti / NVIDIA GeForce RT...
# Name: 50, dtype: object
# ASUS ZenBook 13 UX331UA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c80378215d1b> in <module>
#     275
#     276 print('на вход', len(df_for_parse))
# --> 277 parsed_df = price_parsing1(df_for_parse)
#     278 print('на выход', len(parsed_df))
#     279
#
# <ipython-input-7-c80378215d1b> in price_parsing1(df)
#     258     try:
#     259
# --> 260         df[df['Quantaty'].isna() == True] = df[df['Quantaty'].isna() == True].apply(model_page_parsing_v2, axis = 1)
#     261
#     262     except Exception as Err:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-7-c80378215d1b> in model_page_parsing_v2(model_df)
#     200                             offers_href = 'https://market.yandex.ru' + str(prices_count_cell.find('a').get('href'))
#     201                             ref_href = 'https://market.yandex.ru' + model_df['Href']
# --> 202                             offers_price_list = pd.Series(offers_prices_harvest(offers_href, ref_href, model_df['Quantaty']))
#     203                             model_df['AvgPrice'] = offers_price_list.mean()
#     204                             model_df['MinPrice'] = offers_price_list.min()
#
# <ipython-input-7-c80378215d1b> in offers_prices_harvest(offers_href, ref_href, offers_q)
#      92                                         cookies = cookies())
#      93             if offers_response.status_code == 200:
# ---> 94                 offers_page = BeautifulSoup(offers_response.text,'html.parser')
#      95
#      96                 page_prices = offers_page.find_all('div', class_='price')
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     279             self.reset()
#     280             try:
# --> 281                 self._feed()
#     282                 break
#     283             except ParserRejectedMarkup:
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     340         self.builder.reset()
#     341
# --> 342         self.builder.feed(self.markup)
#     343         # Close out any unfinished strings and close all the open tags.
#     344         self.endData()
#
# ~\Anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     245         parser.soup = self.soup
#     246         try:
# --> 247             parser.feed(markup)
#     248             parser.close()
#     249         except HTMLParseError as e:
#
# ~\Anaconda3\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~\Anaconda3\lib\html\parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~\Anaconda3\lib\html\parser.py in parse_starttag(self, i)
#     324                 attrvalue = attrvalue[1:-1]
#     325             if attrvalue:
# --> 326                 attrvalue = unescape(attrvalue)
#     327             attrs.append((attrname.lower(), attrvalue))
#     328             k = m.end()
#
# ~\Anaconda3\lib\html\__init__.py in unescape(s)
#     130     if '&' not in s:
#     131         return s
# --> 132     return _charref.sub(_replace_charref, s)
#
# ~\Anaconda3\lib\html\__init__.py in _replace_charref(s)
#     107         # named charref
#     108         if s in _html5:
# --> 109             return _html5[s]
#     110         # find the longest matching name (as defined by the standard)
#     111         for x in range(len(s)-1, 1, -1):
#
# KeyboardInterrupt:

# %%
drop_df = pd.read_excel('Price_link_list/Часы-ссылки на прайсы от 2019-10-10--16-59.xlsx', index_col=0)
print(len(drop_df))
drop_df.drop_duplicates(inplace = True)


drop_df.to_excel('Price_link_list/Часы-c-SIM от 2019-10-10--16-59_drop.xlsx')
print(len(drop_df))

# %%
a = pd.DataFrame({'A':[1,2,3,4],
                 'B':[4,5,6,7]})

list(a.columns)

# %%
a = list()
a = [1, 2, 3]

b = pd.Series(a)
b
